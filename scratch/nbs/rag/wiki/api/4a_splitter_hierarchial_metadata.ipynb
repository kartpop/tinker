# %%
from pathlib import Path
from haystack.components.converters import TextFileToDocument

converter = TextFileToDocument()

docs = converter.run(sources=[Path("dinosaur-page.html")])
print(docs)
# Out:
# {'documents': [Document(id=cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32, content: '<link
#   rel="mw-deduplicated-inline-style"
#   href="mw-data:TemplateStyles:r1236090951"
# />
# <p class="...', meta: {'file_path': 'dinosaur-page.html'})]}

# %%
from bs4 import BeautifulSoup
import re

def WikiPageChunks(html_str: str) -> list:
    soup = BeautifulSoup(html_str, 'html.parser')

    chunks = []

    def clean_text(text):
        cleaned_text = text.replace('\n', ' ').replace('\xa0', ' ')
        cleaned_text = re.sub(r'\s+', ' ', cleaned_text)
        cleaned_text = re.sub(r'(\d)\s+(\d)', r'\1\2', cleaned_text)
        cleaned_text = cleaned_text.strip()
        return cleaned_text

    html_soup = soup.body or soup
    nested = ['ul', 'ol', 'dl', 'li', 'dt', 'dd']
    for tag in html_soup.find_all(recursive=False):
        if tag.name == 'p':
            chunks.append(clean_text(tag.get_text(separator=' ')))
        elif tag.name == 'link':
            continue
        elif tag.name in nested:
            list_items = tag.find_all('li')
            list_text = ' '.join([f"- {clean_text(li.get_text(separator=' '))}" for li in list_items])
            chunks.append(list_text)
        else:
            chunks.append(str(tag))
    
    return chunks

# %%
html_content = docs["documents"][0].content

# %% [markdown]
# ## Custom splitter which captures hierarchial metadata

# %%
from haystack import Document
from haystack import component
from typing import List
import uuid

@component
class WikiPageChunker:
    """
    A component that splits the content of Wikipedia pages into chunks.
    - The document content is expected to be in HTML format fetched via wikipediaapi and
    which has been run through TextFileToDocument converter.
    - Each chunk is a paragraph, list, or table in the Wikipedia page.
    - Each chunk is stored as a separate document with text in 'content' field
    - Each chunk also stores title, h2, h3 etc in meta field.
    - Custom component also creates a hierarchial structure of the chunks based on title, h2, h3 etc.
    """
    @component.output_types(documents=List[Document])
    def run(self, documents: List[Document]):
        chunks = []
        for doc in documents:
            html_content = doc.content
            page_chunks = WikiPageChunks(html_content)
            i = 0
            current_h2 = ""
            current_h3 = ""
            current_h4 = ""
            # Add more headers if needed

            for chunk in page_chunks:
                if chunk == "":
                    continue
                if chunk.startswith("<h2>"):
                    current_h2 = chunk[4:-5]  # Extract text between <h2> and </h2>
                    current_h3 = ""  # Reset h3 when a new h2 is found
                    current_h4 = ""  # Reset h4 when a new h2 is found
                elif chunk.startswith("<h3>"):
                    current_h3 = chunk[4:-5]  # Extract text between <h3> and </h3>
                    current_h4 = ""  # Reset h4 when a new h3 is found
                elif chunk.startswith("<h4>"):
                    current_h4 = chunk[4:-5]  # Extract text between <h4> and </h4>
                else:
                    meta = {
                        "file_path": doc.meta["file_path"],
                        "source_id": doc.id,
                        "split_id": i,
                        "title": "Dinosaurs"
                    }
                    if current_h2:
                        meta["h2"] = current_h2
                    if current_h3:
                        meta["h3"] = current_h3
                    if current_h4:
                        meta["h4"] = current_h4

                    chunks.append(
                        Document(
                            id=str(uuid.uuid4()),
                            content=chunk,
                            meta=meta
                        )
                    )
                    i += 1
        
        return {"documents": chunks}

# %%
splitter = WikiPageChunker()

chunks = splitter.run(docs["documents"])

chunks
# Out:
# {'documents': [Document(id=4a0a9cc6-2594-4c9d-a5f5-b1e078005bdf, content: 'Dinosaurs are a diverse group of reptiles of the clade Dinosauria . They first appeared during the T...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 0, 'title': 'Dinosaurs'}),
#   Document(id=356b86c0-1d0a-44a7-9cb2-11e6fe29dfa3, content: 'Dinosaurs are varied from taxonomic, morphological and ecological standpoints. Birds, at over 11,000...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 1, 'title': 'Dinosaurs'}),
#   Document(id=07b0a134-911c-4697-8b17-be8f26c71161, content: 'While dinosaurs were ancestrally bipedal, many extinct groups included quadrupedal species, and some...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 2, 'title': 'Dinosaurs'}),
#   Document(id=1e1294ff-aed6-4758-a1a6-f28969b3bc40, content: 'The first dinosaur fossils were recognized in the early 19th century, with the name "dinosaur" (mean...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 3, 'title': 'Dinosaurs'}),
#   Document(id=4700a2a4-1780-4b67-b535-08f9924e8959, content: 'Under phylogenetic nomenclature, dinosaurs are usually defined as the group consisting of the most r...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 4, 'title': 'Dinosaurs', 'h2': 'Definition'}),
#   Document(id=1afd72df-0b55-4c2e-a9d5-dafb2279d941, content: 'Birds are the sole surviving dinosaurs. In traditional taxonomy, birds were considered a separate cl...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 5, 'title': 'Dinosaurs', 'h2': 'Definition'}),
#   Document(id=32ba1edb-618e-48fc-9734-64421c6acef0, content: 'Research by Matthew G. Baron, David B. Norman, and Paul M. Barrett in 2017 suggested a radical revis...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 6, 'title': 'Dinosaurs', 'h2': 'Definition'}),
#   Document(id=16e357f5-14fb-4409-b9ee-e30492cf0723, content: 'Using one of the above definitions, dinosaurs can be generally described as archosaurs with hind lim...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 7, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'General description'}),
#   Document(id=6ae6af47-1a92-4133-bc5b-b7bc10747c00, content: 'Dinosaurs were the dominant terrestrial vertebrates of the Mesozoic Era, especially the Jurassic and...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 8, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'General description'}),
#   Document(id=453f43d8-fae4-46ee-8919-7edffaaa93e9, content: 'Extinct dinosaurs, as well as modern birds, include genera that are herbivorous and others carnivoro...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 9, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'General description'}),
#   Document(id=67401288-0cdf-4ff8-b43e-1cfbf928e757, content: 'While recent discoveries have made it more difficult to present a universally agreed-upon list of th...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 10, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#   Document(id=b328f66a-ce13-4d9b-a5ba-f807b8ee652d, content: 'A detailed assessment of archosaur interrelations by Sterling Nesbitt confirmed or found the followi...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 11, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#   Document(id=73f56119-0d7e-48ef-a3af-b5e14c7ee92a, content: '- In the skull, a supratemporal fossa (excavation) is present in front of the supratemporal fenestra...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 12, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#   Document(id=87ab9175-7da6-4d54-8bd7-bfcf17285241, content: 'Nesbitt found a number of further potential synapomorphies and discounted a number of synapomorphies...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 13, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#   Document(id=5b9474ba-41ec-429c-a4dd-e8cac328ba96, content: 'A variety of other skeletal features are shared by dinosaurs. However, because they either are commo...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 14, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#   Document(id=1d606ef4-b61e-4c05-9f33-998f35814a68, content: 'Dinosaurs stand with their hind limbs erect in a manner similar to most modern mammals, but distinct...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 15, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#   Document(id=cd3d9a18-db95-4e11-99cd-20cef1d4bf03, content: 'Dinosaur fossils have been known for millennia, although their true nature was not recognized. The C...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 16, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Pre-scientific history'}),
#   Document(id=586d7c69-df3a-4ca1-b74d-6fc748eed9e7, content: 'Scholarly descriptions of what would now be recognized as dinosaur bones first appeared in the late ...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 17, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Early dinosaur research'}),
#   Document(id=57625b74-fcf4-4fb5-94f0-b5aa77287f14, content: 'Between 1815 and 1824, the Rev William Buckland, the first Reader of Geology at the University of Ox...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 18, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Early dinosaur research'}),
#   Document(id=745207cb-f4c8-45e2-adfa-63861f92a956, content: 'The study of these "great fossil lizards" soon became of great interest to European and American sci...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 19, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Early dinosaur research'}),
#   Document(id=37ee66fe-ac9a-4522-854e-90e2ca00bba6, content: 'In 1858, William Parker Foulke discovered the first known American dinosaur, in marl pits in the sma...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 20, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Discoveries in North America'}),
#   Document(id=83d274a5-1113-4012-bdc3-e0c16c2f3d26, content: 'Dinosaur mania was exemplified by the fierce rivalry between Edward Drinker Cope and Othniel Charles...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 21, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Discoveries in North America'}),
#   Document(id=20d92a3f-aa94-4c4f-8679-c99233e57ae1, content: 'World War II caused a pause in palaeontological research; after the war, research attention was also...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 22, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': '"Dinosaur renaissance" and beyond'}),
#   Document(id=f468c710-acd6-4043-9ca1-039716c582f4, content: 'New revelations were supported by an increase in dinosaur discoveries. Major new dinosaur discoverie...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 23, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': '"Dinosaur renaissance" and beyond'}),
#   Document(id=4a58feeb-74a3-4606-89d7-fb5fcc382f13, content: 'Prior to the dinosaur renaissance, dinosaurs were mostly classified using the traditional rank-based...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 24, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': '"Dinosaur renaissance" and beyond'}),
#   Document(id=48d5055a-da61-4e8d-b8eb-9a8d1de17d30, content: 'Dinosaur fossils are not limited to bones, but also include imprints or mineralized remains of skin ...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 25, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Soft tissue and molecular preservation'}),
#   Document(id=1364173b-6594-4f8c-b5b7-aeffc3fd7e24, content: 'Starting from the 1990s, major discoveries of exceptionally preserved fossils in deposits known as c...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 26, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Soft tissue and molecular preservation'}),
#   Document(id=3006c212-e060-4368-8994-5bb0a1b0e578, content: 'Concurrently, a line of work led by Mary Higby Schweitzer, Jack Horner, and colleagues reported vari...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 27, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Soft tissue and molecular preservation'}),
#   Document(id=02fb4f44-99bd-4ab4-ad95-cd5db81ff279, content: 'Dinosaurs diverged from their archosaur ancestors during the Middle to Late Triassic epochs, roughly...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 28, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Origins and early evolution'}),
#   Document(id=15950a39-1fec-4f47-a0ad-5aa83d6a201d, content: 'The Ischigualasto Formation (radiometrically dated at 231-230 million years old) has produced the ea...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 29, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Origins and early evolution'}),
#   Document(id=a28497b3-575e-4bc8-96c1-b0e7b2d55372, content: 'Less well-preserved remains of the sauropodomorphs Jaklapallisaurus and Nambalia , along with the ea...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 30, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Origins and early evolution'}),
#   Document(id=8bc66e62-411a-4db1-8104-fdc20ff66364, content: 'When dinosaurs appeared, they were not the dominant terrestrial animals. The terrestrial habitats we...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 31, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Origins and early evolution'}),
#   Document(id=8dce8a78-a8ad-4aa8-b924-ba9843a05049, content: 'Dinosaur evolution after the Triassic followed changes in vegetation and the location of continents....', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 32, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Evolution and paleobiogeography'}),
#   Document(id=c9b20cf0-b420-46a5-ba80-aec1a365829d, content: 'By the Early Cretaceous and the ongoing breakup of Pangaea, dinosaurs were becoming strongly differe...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 33, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Evolution and paleobiogeography'}),
#   Document(id=1e21f3e6-7301-4dcc-88f7-e82aaefd61a6, content: 'There were three general dinosaur faunas in the Late Cretaceous. In the northern continents of North...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 34, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Evolution and paleobiogeography'}),
#   Document(id=5f05135b-12ed-4862-b6d7-a5c9c2f4e06a, content: 'The Cretaceous–Paleogene extinction event, which occurred approximately 66 million years ago at the ...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 35, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Evolution and paleobiogeography'}),
#   Document(id=4c046427-db18-446f-a90a-380505144ce4, content: 'The surviving lineages of neornithine birds, including the ancestors of modern ratites, ducks and ch...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 36, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Evolution and paleobiogeography'}),
#   Document(id=dc3beef1-c20f-4e08-83cf-b1bf7e40b82f, content: 'Dinosaurs belong to a group known as archosaurs, which also includes modern crocodilians. Within the...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 37, 'title': 'Dinosaurs', 'h2': 'Classification'}),
#   Document(id=55004a56-903d-46f3-9668-069ba39c07d8, content: 'Collectively, dinosaurs as a clade are divided into two primary branches, Saurischia and Ornithischi...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 38, 'title': 'Dinosaurs', 'h2': 'Classification'}),
#   Document(id=4e745426-0fe3-4357-b785-114f7c7aa931, content: 'By contrast, ornithischians—"bird-hipped", from the Greek ornitheios (ὀρνίθειος) meaning "of a bird"...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 39, 'title': 'Dinosaurs', 'h2': 'Classification'}),
#   Document(id=4e7506e4-187c-4899-93f5-1b38a62eb886, content: 'Despite the terms "bird hip" (Ornithischia) and "lizard hip" (Saurischia), birds are not part of Orn...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 40, 'title': 'Dinosaurs', 'h2': 'Classification'}),
#   Document(id=60d25649-5c01-4345-bddd-e424955fcb9a, content: 'The following is a simplified classification of dinosaur groups based on their evolutionary relation...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 41, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#   Document(id=71b93add-d91f-41cd-a283-dbbb59ed5757, content: '- Dinosauria', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 42, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#   Document(id=8eeaff14-a215-4ecc-b3c5-da2a4a3e9fcf, content: '- †Ornithischia ("bird-hipped"; diverse bipedal and quadrupedal herbivores) - †Saphornithischia ("tr...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 43, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#   Document(id=8635cd42-0f4e-4f51-a95f-8c6948add569, content: '- †Pachycephalosauria (bipeds with domed or knobby growth on skulls) - †Ceratopsia (bipeds and quadr...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 44, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#   Document(id=ca2990cd-ba41-4c39-a44d-6114c30d76b2, content: '- †Sauropodomorpha (herbivores with small heads, long necks, and long tails) - †Unaysauridae (primit...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 45, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#   Document(id=b98dfee0-e8d6-4431-b147-57a288c40c09, content: '- †Alvarezsauroidea (small hunters with reduced forelimbs) - †Alvarezsauridae (insectivores with onl...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 46, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#   Document(id=ceee1b2e-5fb6-459d-8f4a-c870764dd66a, content: 'Timeline of major dinosaur groups per Holtz (2007).', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 47, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Timeline of major groups'}),
#   Document(id=fdc343bd-c5b4-4aee-9e91-9bcc169645ee, content: 'Knowledge about dinosaurs is derived from a variety of fossil and non-fossil records, including foss...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 48, 'title': 'Dinosaurs', 'h2': 'Paleobiology'}),
#   Document(id=9d0aeb94-8bbb-4455-87b2-e35372523f6d, content: 'Current evidence suggests that dinosaur average size varied through the Triassic, Early Jurassic, La...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 49, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Size'}),
#   Document(id=b742f0f4-747f-42c8-a0d8-4bc1de3cf4be, content: 'The sauropods were the largest and heaviest dinosaurs. For much of the dinosaur era, the smallest sa...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 50, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Size'}),
#   Document(id=e8be4de6-c64f-43b2-88e4-e987fee9e99a, content: 'Scientists will probably never be certain of the largest and smallest dinosaurs to have ever existed...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 51, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Size', 'h4': 'Largest and smallest'}),
#   Document(id=da6532ee-b370-4bf0-b3fb-c976a446b2c5, content: 'The tallest and heaviest dinosaur known from good skeletons is Giraffatitan brancai (previously clas...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 52, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Size', 'h4': 'Largest and smallest'}),
#   Document(id=c5fe945c-be86-4ffd-95e5-6b5168501e2e, content: 'There were larger dinosaurs, but knowledge of them is based entirely on a small number of fragmentar...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 53, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Size', 'h4': 'Largest and smallest'}),
#   Document(id=5a0eddf9-bd8b-40fa-a397-6eaad93fdfbe, content: 'The largest carnivorous dinosaur was Spinosaurus , reaching a length of 12.6 to 18 meters (41 to 59 ...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 54, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Size', 'h4': 'Largest and smallest'}),
#   Document(id=11c042aa-20ff-4e52-88ef-376e30c80a0e, content: 'The smallest dinosaur known is the bee hummingbird, with a length of only 5 centimeters (2.0 in) and...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 55, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Size', 'h4': 'Largest and smallest'}),
#   Document(id=cc9b717c-7060-48c6-8eb7-63067f80675d, content: 'Many modern birds are highly social, often found living in flocks. There is general agreement that s...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 56, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Behavior'}),
#   Document(id=562162a5-584b-4e6f-96a1-edec85bfc4db, content: 'The first potential evidence for herding or flocking as a widespread behavior common to many dinosau...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 57, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Behavior'}),
#   Document(id=7d76d26b-5637-4b9a-9e9b-f79c36cde369, content: 'The crests and frills of some dinosaurs, like the marginocephalians, theropods and lambeosaurines, m...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 58, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Behavior'}),
#   Document(id=b5a871ba-7080-47c0-9119-f5a502ca537e, content: 'From a behavioral standpoint, one of the most valuable dinosaur fossils was discovered in the Gobi D...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 59, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Behavior'}),
#   Document(id=4995df02-9fa7-4f2d-808b-248b3c5b705a, content: 'Comparisons between the scleral rings of dinosaurs and modern birds and reptiles have been used to i...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 60, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Behavior'}),
#   Document(id=be75e688-4389-4b01-ad69-f9954ee2ac61, content: 'Based on fossil evidence from dinosaurs such as Oryctodromeus , some ornithischian species seem to h...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 61, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Behavior'}),
#   Document(id=77213266-4abc-4fff-9d22-1c987aa27fd0, content: 'Modern birds communicate by visual and auditory signals, and the wide diversity of visual display st...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 62, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Communication'}),
#   Document(id=eaa370b5-7a6e-40d2-b218-fe3714f06b21, content: 'On the basis that non-avian dinosaurs did not have syrinxes and that their next close living relativ...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 63, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Communication'}),
#   Document(id=a768934a-6d0f-4514-879a-8684a999878f, content: 'In 2023, a fossilized larynx was described, from a specimen of the ankylosaurid Pinacosaurus . The s...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 64, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Communication'}),
#   Document(id=1e9f0e34-88d4-41f4-a9fb-86fa369d49f3, content: 'All dinosaurs laid amniotic eggs. Dinosaur eggs were usually laid in a nest. Most species create som...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 65, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Reproductive biology'}),
#   Document(id=9f59c8a0-b521-41c5-b046-bed1b132b330, content: 'When laying eggs, females grow a special type of bone between the hard outer bone and the marrow of ...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 66, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Reproductive biology'}),
#   Document(id=95035635-4319-46ce-a776-ac3625cf32ae, content: 'Another widespread trait among modern birds (but see below in regards to fossil groups and extant me...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 67, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Reproductive biology'}),
#   Document(id=e7579d00-a10b-4b50-9fd0-98d3a91dbaec, content: 'However, there is ample evidence of precociality or superprecociality among many dinosaur species, p...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 68, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Reproductive biology'}),
#   Document(id=50814900-a6c4-4e15-8a0c-1118fa19398b, content: 'Genital structures are unlikely to fossilize as they lack scales that may allow preservation via pig...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 69, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Reproductive biology'}),
#   Document(id=8bcab11a-62f9-42fe-a4d4-c9d197f9aabe, content: 'Because both modern crocodilians and birds have four-chambered hearts (albeit modified in crocodilia...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 70, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Physiology'}),
#   Document(id=9abe0c3c-6671-4234-8018-183e39ce6828, content: 'After non-avian dinosaurs were discovered, paleontologists first posited that they were ectothermic....', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 71, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Physiology'}),
#   Document(id=98cbff9c-d142-49e1-8c37-410ddd238d57, content: 'One of the greatest contributions to the modern understanding of dinosaur physiology has been paleoh...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 72, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Physiology'}),
#   Document(id=9c9fb167-9c92-4178-88f4-c51fc3b8b928, content: 'In saurischian dinosaurs, higher metabolisms were supported by the evolution of the avian respirator...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 73, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Physiology'}),
#   Document(id=04448feb-27f6-49de-ab22-75378ed9bc15, content: 'Like other reptiles, dinosaurs are primarily uricotelic, that is, their kidneys extract nitrogenous ...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 74, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Physiology'}),
#   Document(id=a2f3ea9b-fd6e-4c0b-86f9-54b2423f3391, content: 'The size and shape of the brain can be partly reconstructed based on the surrounding bones. In 1896,...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 75, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Physiology'}),
#   Document(id=56104eb8-5dbc-4afa-9be5-6a4b08e9e820, content: 'The possibility that dinosaurs were the ancestors of birds was first suggested in 1868 by Thomas Hen...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 76, 'title': 'Dinosaurs', 'h2': 'Origin of birds'}),
#   Document(id=e9c571e7-5a4b-401a-bc03-e187a1a73249, content: 'Feathers are one of the most recognizable characteristics of modern birds, and a trait that was also...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 77, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Feathers'}),
#   Document(id=142cefe6-2a1a-48ca-9883-1b1a2e06874c, content: 'However, researchers do not agree regarding whether these structures share a common origin between l...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 78, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Feathers'}),
#   Document(id=7d1e60a3-cd78-4e18-bec1-0144bb9f3759, content: 'Archaeopteryx was the first fossil found that revealed a potential connection between dinosaurs and ...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 79, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Feathers'}),
#   Document(id=a5d7a3a9-db96-490c-87e8-b1d8c8ac3d67, content: 'Because feathers are often associated with birds, feathered dinosaurs are often touted as the missin...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 80, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Skeleton'}),
#   Document(id=4d1682d9-617a-489d-8006-51f211da5503, content: 'Large meat-eating dinosaurs had a complex system of air sacs similar to those found in modern birds,...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 81, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Soft anatomy'}),
#   Document(id=90eed1a4-a367-410e-9d57-bd8f0ca4d345, content: 'Fossils of the troodonts Mei and Sinornithoides demonstrate that some dinosaurs slept with their hea...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 82, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Behavioral evidence'}),
#   Document(id=d4b8a5a7-4889-4501-b851-af07fb7bb5ba, content: 'Some dinosaurs are known to have used gizzard stones like modern birds. These stones are swallowed b...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 83, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Behavioral evidence'}),
#   Document(id=79d46405-7b20-4ff6-93e8-fe32c8a6456e, content: 'All non-avian dinosaurs and most lineages of birds became extinct in a mass extinction event, called...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 84, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups'}),
#   Document(id=2e13993f-0bae-4b83-b0e3-6e378d0564d3, content: 'Just before the K-Pg extinction event, the number of non-avian dinosaur species that existed globall...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 85, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Pre-extinction diversity'}),
#   Document(id=84feff92-e066-43d5-a928-4d8d28a6381b, content: 'The bolide impact hypothesis, first brought to wide attention in 1980 by Walter Alvarez, Luis Alvare...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 86, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Impact event'}),
#   Document(id=c6fde57c-e40c-4a7a-92df-e36879c7d6d0, content: 'Within hours, the Chicxulub impact would have created immediate effects such as earthquakes, tsunami...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 87, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Impact event'}),
#   Document(id=8330669a-434a-4a09-b47e-4b6d483bc000, content: 'At the time of the K-Pg extinction, the Deccan Traps flood basalts of India were actively erupting. ...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 88, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Deccan Traps'}),
#   Document(id=3d1daad9-203a-4826-88f7-9a094774bbf6, content: 'Before 2000, arguments that the Deccan Traps eruptions—as opposed to the Chicxulub impact—caused the...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 89, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Deccan Traps'}),
#   Document(id=f2bd312d-0fb6-4b2f-8fda-3bc0ee0c3664, content: 'Whether the Deccan Traps were a major cause of the extinction, on par with the Chicxulub impact, rem...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 90, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Deccan Traps'}),
#   Document(id=f36304b0-b6f3-45b2-914f-ff51dd88a819, content: 'Non-avian dinosaur remains have occasionally been found above the K-Pg boundary. In 2000, Spencer Lu...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 91, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Possible Paleocene survivors'}),
#   Document(id=24653ab5-1c64-42f3-ac37-c5935eb2a509, content: 'By human standards, dinosaurs were creatures of fantastic appearance and often enormous size. As suc...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 92, 'title': 'Dinosaurs', 'h2': 'Cultural depictions'}),
#   Document(id=912fb7d2-ce51-4bc9-9c8d-16daf3433454, content: 'Public enthusiasm for dinosaurs first developed in Victorian England, where in 1854, three decades a...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 93, 'title': 'Dinosaurs', 'h2': 'Cultural depictions'}),
#   Document(id=d0af17b2-37a6-4c86-93e1-ffb9b74cb17d, content: 'The popular preoccupation with dinosaurs has ensured their appearance in literature, film, and other...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 94, 'title': 'Dinosaurs', 'h2': 'Cultural depictions'}),
#   Document(id=723e2af8-6668-4bfa-9aca-2667ed6411f8, content: '- Dinosaur diet and feeding - Evolutionary history of life - Lists of dinosaur-bearing stratigraphic...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 95, 'title': 'Dinosaurs', 'h2': 'See also'}),
#   Document(id=69a06f94-e5cd-4ff7-b1d2-320a46efb145, content: '- University of Southampton (September 29, 2021). "Two New Species of Large Predatory Dinosaur With ...', meta: {'file_path': 'dinosaur-page.html', 'source_id': 'cccb7d931975c65babedb9ad3867015939fba680621923f60517da5e5dea3c32', 'split_id': 96, 'title': 'Dinosaurs', 'h2': 'Further reading'})]}
