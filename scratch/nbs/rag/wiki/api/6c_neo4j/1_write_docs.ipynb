# %% [markdown]
# ### Write Documents to Neo4j using haystack integration

# %%
from pathlib import Path
from haystack.components.converters import TextFileToDocument

converter = TextFileToDocument()

docs = converter.run(sources=[Path("Dinosaur.html")])
print(docs)
# Out:
# {'documents': [Document(id=93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e, content: '<link
#   rel="mw-deduplicated-inline-style"
#   href="mw-data:TemplateStyles:r1236090951"
# />
# <p class="...', meta: {'file_path': 'Dinosaur.html'})]}

# %% [markdown]
# ***Note: TextFileToDocument inbuilt component/converter takes >2 seconds to execute! Let's create a custom component.***

# %%
from pathlib import Path
import uuid
from haystack import Document

# Read the content of Dinosaur.html
html_path = Path("Dinosaur.html")
html_content = html_path.read_text()

# Create a Document object with a new UUID
doc = Document(
    id=str(uuid.uuid4()),
    content=html_content,
    meta={"file_path": "Dinosaur.html"}
)

# Create the dict object
docs_dict = {"documents": [doc]}

print(docs_dict)
# Out:
# {'documents': [Document(id=9236d65f-85a6-432a-867c-3bd9da3a578c, content: '<link
#   rel="mw-deduplicated-inline-style"
#   href="mw-data:TemplateStyles:r1236090951"
# />
# <p class="...', meta: {'file_path': 'Dinosaur.html'})]}

# %%
from bs4 import BeautifulSoup
import re

def WikiPageChunks(html_str: str) -> list:
    soup = BeautifulSoup(html_str, 'html.parser')  # Parse the HTML content

    chunks = []

    def clean_text(text):
        cleaned_text = text.replace('\n', ' ').replace('\xa0', ' ')  # Replace newlines and non-breaking spaces with regular spaces
        cleaned_text = re.sub(r'\s+', ' ', cleaned_text)  # Replace multiple spaces with a single space
        cleaned_text = re.sub(r'(\d)\s+(\d)', r'\1\2', cleaned_text)  # Remove spaces between digits
        cleaned_text = cleaned_text.strip()  # Remove leading and trailing spaces
        return cleaned_text

    html_soup = soup.body or soup  # Use the body of the HTML if it exists, otherwise use the whole soup
    nested = ['ul', 'ol', 'dl', 'li', 'dt', 'dd']  # Tags that represent nested lists
    for tag in html_soup.find_all(recursive=False):  # Iterate over top-level tags in the HTML
        if tag.name == 'p':
            chunks.append(clean_text(tag.get_text(separator=' ')))  # Clean and add paragraph text to chunks
        elif tag.name == 'link':
            continue  # Skip link tags
        elif tag.name in nested:
            list_items = tag.find_all('li')  # Find all list items
            for li in list_items:
                chunks.append(clean_text(li.get_text(separator=' ')))  # Clean and add each list item text to chunks
        else:
            chunks.append(str(tag))  # Add other tags as strings
    
    return chunks

# %%
html_content = docs_dict["documents"][0].content

# %%
from typing import List, Dict, Any
import uuid
from haystack import Document
from haystack import component

class Chunk:
    def __init__(self, id: str, next: str = None):
        self.id = id
        # self.next = next

class Section:
    def __init__(self, name: str, type: str):
        self.name = name
        self.type = type
        self.chunks = []
        self.sections = []
        # self.first_chunk = None

class Page:
    def __init__(self, title: str):
        self.title = title
        self.sections = []
        self.chunks = []
        # self.first_chunk = None

@component
class WikiPageChunker:
    """
    A component that splits the content of Wikipedia pages into chunks.
    - The document content is expected to be in HTML format fetched via wikipediaapi and
    which has been run through TextFileToDocument converter.
    - Each chunk is a paragraph, list, or table in the Wikipedia page.
    - Each chunk is stored as a separate document with text in 'content' field
    - Each chunk also stores title, h2, h3 etc in meta field.
    - Custom component also creates a hierarchical structure of the chunks based on title, h2, h3 etc.
    """
    @component.output_types(documents=List[Document], hierarchy=dict)
    def run(self, documents: List[Document]):
        chunks = []
        hierarchy = {}
        
        for doc in documents:
            page_title = doc.meta["file_path"].replace(".html", "")
            page = Page(page_title)
            
            html_content = doc.content
            page_chunks = WikiPageChunks(html_content)
            i = 0
            current_h2 = ""
            current_h3 = ""
            current_h4 = ""
            current_section = None
            current_sub_section = None
            current_sub_sub_section = None

            for chunk in page_chunks:
                if chunk == "":
                    continue
                if chunk.startswith("<h2>"):
                    current_h2 = chunk[4:-5]  # Extract text between <h2> and </h2>
                    current_h3 = ""  # Reset h3 when a new h2 is found
                    current_h4 = ""  # Reset h4 when a new h2 is found
                    current_section = Section(current_h2, "h2")
                    page.sections.append(current_section)
                    current_sub_section = None
                    current_sub_sub_section = None
                elif chunk.startswith("<h3>"):
                    current_h3 = chunk[4:-5]  # Extract text between <h3> and </h3>
                    current_h4 = ""  # Reset h4 when a new h3 is found
                    if current_section:
                        current_sub_section = Section(current_h3, "h3")
                        current_section.sections.append(current_sub_section)
                        current_sub_sub_section = None
                elif chunk.startswith("<h4>"):
                    current_h4 = chunk[4:-5]  # Extract text between <h4> and </h4>
                    if current_sub_section:
                        current_sub_sub_section = Section(current_h4, "h4")
                        current_sub_section.sections.append(current_sub_sub_section)
                else:
                    meta = {
                        "file_path": doc.meta["file_path"],
                        "source_id": doc.id,
                        "split_id": i,
                        "title": "Dinosaurs"
                    }
                    if current_h2:
                        meta["h2"] = current_h2
                    if current_h3:
                        meta["h3"] = current_h3
                    if current_h4:
                        meta["h4"] = current_h4

                    chunk_obj = Chunk(str(uuid.uuid4()))
                    chunks.append(
                        Document(
                            id=chunk_obj.id,
                            content=chunk,
                            meta=meta
                        )
                    )
                    if current_sub_sub_section:
                        current_sub_sub_section.chunks.append(chunk_obj)
                        # if current_sub_sub_section.first_chunk is None:
                        #     current_sub_sub_section.first_chunk = chunk_obj
                    elif current_sub_section:
                        current_sub_section.chunks.append(chunk_obj)
                        # if current_sub_section.first_chunk is None:
                        #     current_sub_section.first_chunk = chunk_obj
                    elif current_section:
                        current_section.chunks.append(chunk_obj)
                        # if current_section.first_chunk is None:
                        #     current_section.first_chunk = chunk_obj
                    else:
                        page.chunks.append(chunk_obj)
                        # if page.first_chunk is None:
                        #     page.first_chunk = chunk_obj
                    i += 1
            
            # self.set_next_chunks(page)
            hierarchy[page_title] = self.page_to_dict(page)
        
        return {"documents": chunks, "hierarchy": hierarchy}

    # def set_next_chunks(self, page: Page):
    #     for section in page.sections:
    #         self.set_next_chunks_in_section(section)
    #     self.set_next_in_list(page.chunks)

    # def set_next_chunks_in_section(self, section: Section):
    #     for sub_section in section.sections:
    #         self.set_next_chunks_in_section(sub_section)
    #     self.set_next_in_list(section.chunks)

    # def set_next_in_list(self, chunks: List[Chunk]):
    #     for i in range(len(chunks) - 1):
    #         chunks[i].next = chunks[i + 1].id
    #     if chunks:
    #         chunks[-1].next = None

    def page_to_dict(self, page: Page) -> Dict[str, Any]:
        return {
            "title": page.title,
            "sections": [self.section_to_dict(section) for section in page.sections],
            "chunks": [self.chunk_to_dict(chunk) for chunk in page.chunks],
            # "first_chunk": self.chunk_to_dict(page.first_chunk) if page.first_chunk else None
        }

    def section_to_dict(self, section: Section) -> Dict[str, Any]:
        return {
            "name": section.name,
            "type": section.type,
            "chunks": [self.chunk_to_dict(chunk) for chunk in section.chunks],
            "sections": [self.section_to_dict(sub_section) for sub_section in section.sections],
            # "first_chunk": self.chunk_to_dict(section.first_chunk) if section.first_chunk else None
        }

    def chunk_to_dict(self, chunk: Chunk) -> Dict[str, Any]:
        return {
            "id": chunk.id,
            # "next": chunk.next
        }

# %%
splitter = WikiPageChunker()

chunk_result = splitter.run(docs_dict["documents"])

chunk_result["documents"]
# Out:
# [Document(id=157fe7b1-3e3f-40dc-b7da-e6320557d55d, content: 'Dinosaurs are a diverse group of reptiles of the clade Dinosauria . They first appeared during the T...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 0, 'title': 'Dinosaurs'}),
#  Document(id=0f9565ed-5f7c-4afa-baec-57d97ae8f1ed, content: 'Dinosaurs are varied from taxonomic, morphological and ecological standpoints. Birds, at over 11,000...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 1, 'title': 'Dinosaurs'}),
#  Document(id=5f1d4df4-5f0e-4707-b231-c33398c1c639, content: 'While dinosaurs were ancestrally bipedal, many extinct groups included quadrupedal species, and some...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 2, 'title': 'Dinosaurs'}),
#  Document(id=d6ec0129-4cdc-489e-991c-82aa74016599, content: 'The first dinosaur fossils were recognized in the early 19th century, with the name "dinosaur" (mean...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 3, 'title': 'Dinosaurs'}),
#  Document(id=cb8a55b6-810a-4459-b2cf-93c07f41c9ec, content: 'Under phylogenetic nomenclature, dinosaurs are usually defined as the group consisting of the most r...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 4, 'title': 'Dinosaurs', 'h2': 'Definition'}),
#  Document(id=4d6d0694-1fe4-48c4-9379-01d826109ca6, content: 'Birds are the sole surviving dinosaurs. In traditional taxonomy, birds were considered a separate cl...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 5, 'title': 'Dinosaurs', 'h2': 'Definition'}),
#  Document(id=a48cb64b-95ea-4800-bbd3-e1ef7727b215, content: 'Research by Matthew G. Baron, David B. Norman, and Paul M. Barrett in 2017 suggested a radical revis...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 6, 'title': 'Dinosaurs', 'h2': 'Definition'}),
#  Document(id=0a920381-9ff3-4bd1-9b3c-632f0aa8ad29, content: 'Using one of the above definitions, dinosaurs can be generally described as archosaurs with hind lim...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 7, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'General description'}),
#  Document(id=00833423-9899-4972-877d-3d7094c99e0a, content: 'Dinosaurs were the dominant terrestrial vertebrates of the Mesozoic Era, especially the Jurassic and...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 8, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'General description'}),
#  Document(id=d1009167-dd39-4144-9a61-eb7a99b22d41, content: 'Extinct dinosaurs, as well as modern birds, include genera that are herbivorous and others carnivoro...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 9, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'General description'}),
#  Document(id=676bc8cb-b102-45a4-b833-33221443d915, content: 'While recent discoveries have made it more difficult to present a universally agreed-upon list of th...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 10, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#  Document(id=fd9e37dc-1cec-40e4-9d6f-26cce1bc870c, content: 'A detailed assessment of archosaur interrelations by Sterling Nesbitt confirmed or found the followi...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 11, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#  Document(id=e5dc260e-0162-405c-a77e-3d22f0d3a476, content: 'In the skull, a supratemporal fossa (excavation) is present in front of the supratemporal fenestra, ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 12, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#  Document(id=f8c8b75e-e34a-4625-8c56-c2ac8a0c4ce4, content: 'Epipophyses, obliquely backward-pointing processes on the rear top corners of the anterior (front) n...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 13, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#  Document(id=2e1d8e4a-ed6e-4558-8f2a-1419aa5aae56, content: 'Apex of a deltopectoral crest (a projection on which the deltopectoral muscles attach) located at or...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 14, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#  Document(id=74926ec4-9dd2-4165-a6f3-23333532ab53, content: 'Radius, a lower arm bone, shorter than 80% of humerus length', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 15, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#  Document(id=e5eba7bf-ae55-4980-bca4-86cec1fc3ccb, content: 'Fourth trochanter (projection where the caudofemoralis muscle attaches on the inner rear shaft) on t...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 16, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#  Document(id=c4fc6ffa-9ff9-4b2f-a603-9eb54b1105d7, content: 'Fourth trochanter asymmetrical, with distal, lower, margin forming a steeper angle to the shaft', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 17, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#  Document(id=d7550d1c-3281-45e3-8dad-bfc9b693f368, content: 'On the astragalus and calcaneum, upper ankle bones, the proximal articular facet, the top connecting...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 18, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#  Document(id=04b48d44-acec-4242-9e11-3561f5c86f61, content: 'Exoccipitals (bones at the back of the skull) do not meet along the midline on the floor of the endo...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 19, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#  Document(id=ace78762-890b-42db-a3c7-091e50cbb179, content: 'In the pelvis, the proximal articular surfaces of the ischium with the ilium and the pubis are separ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 20, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#  Document(id=68413975-a527-4740-bd40-96b18749d17a, content: 'Cnemial crest on the tibia (protruding part of the top surface of the shinbone) arcs anterolaterally...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 21, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#  Document(id=630c4cc2-5f23-4e74-a6f9-0db211e7965a, content: 'Distinct proximodistally oriented (vertical) ridge present on the posterior face of the distal end o...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 22, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#  Document(id=1317ecdc-3dc7-4aab-b7dc-f66c3714992b, content: 'Concave articular surface for the fibula of the calcaneum (the top surface of the calcaneum, where i...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 23, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#  Document(id=64f8192c-d631-47c0-acbf-3ec54029f77f, content: 'Nesbitt found a number of further potential synapomorphies and discounted a number of synapomorphies...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 24, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#  Document(id=3c0fdc1b-94de-4f18-abf3-e706d74fad4d, content: 'A variety of other skeletal features are shared by dinosaurs. However, because they either are commo...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 25, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#  Document(id=387ca0da-c3e3-49d3-96c7-9cf37509b4a2, content: 'Dinosaurs stand with their hind limbs erect in a manner similar to most modern mammals, but distinct...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 26, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#  Document(id=890b2d6a-d654-47a7-ba94-8ac1040d8f12, content: 'Dinosaur fossils have been known for millennia, although their true nature was not recognized. The C...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 27, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Pre-scientific history'}),
#  Document(id=283e224c-7db4-4fa3-903d-08d863d2dffb, content: 'Scholarly descriptions of what would now be recognized as dinosaur bones first appeared in the late ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 28, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Early dinosaur research'}),
#  Document(id=dd3b2bd3-a32e-4f1f-a997-38e0bd273b12, content: 'Between 1815 and 1824, the Rev William Buckland, the first Reader of Geology at the University of Ox...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 29, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Early dinosaur research'}),
#  Document(id=ffa3b5c7-0a46-44f4-88c6-84d13aab913f, content: 'The study of these "great fossil lizards" soon became of great interest to European and American sci...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 30, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Early dinosaur research'}),
#  Document(id=c360c1b6-02f6-4662-8ec7-806409ab48ef, content: 'In 1858, William Parker Foulke discovered the first known American dinosaur, in marl pits in the sma...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 31, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Discoveries in North America'}),
#  Document(id=d7028bee-ca3f-4270-9b5f-fcb5fcfaef7f, content: 'Dinosaur mania was exemplified by the fierce rivalry between Edward Drinker Cope and Othniel Charles...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 32, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Discoveries in North America'}),
#  Document(id=41b82a2f-147f-4319-aded-28df5d5eb78d, content: 'World War II caused a pause in palaeontological research; after the war, research attention was also...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 33, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': '"Dinosaur renaissance" and beyond'}),
#  Document(id=5500ee58-98e8-4c4c-b055-9c2e0a8452b0, content: 'New revelations were supported by an increase in dinosaur discoveries. Major new dinosaur discoverie...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 34, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': '"Dinosaur renaissance" and beyond'}),
#  Document(id=09ca21f8-4980-4d92-98a2-a13cf4e9e382, content: 'Prior to the dinosaur renaissance, dinosaurs were mostly classified using the traditional rank-based...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 35, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': '"Dinosaur renaissance" and beyond'}),
#  Document(id=1a5e9256-9726-422e-9ecc-b3548be65af0, content: 'Dinosaur fossils are not limited to bones, but also include imprints or mineralized remains of skin ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 36, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Soft tissue and molecular preservation'}),
#  Document(id=fc0fc126-2f79-44b8-bbc3-825f93e56bd1, content: 'Starting from the 1990s, major discoveries of exceptionally preserved fossils in deposits known as c...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 37, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Soft tissue and molecular preservation'}),
#  Document(id=020c93c6-c105-47d7-8fbe-3dc5cbe72b88, content: 'Concurrently, a line of work led by Mary Higby Schweitzer, Jack Horner, and colleagues reported vari...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 38, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Soft tissue and molecular preservation'}),
#  Document(id=11992020-3225-4ff7-b763-1f8e0b0de756, content: 'Dinosaurs diverged from their archosaur ancestors during the Middle to Late Triassic epochs, roughly...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 39, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Origins and early evolution'}),
#  Document(id=a63c7f71-b749-455e-a5be-897bd7077454, content: 'The Ischigualasto Formation (radiometrically dated at 231-230 million years old) has produced the ea...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 40, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Origins and early evolution'}),
#  Document(id=794fb096-a8dc-4196-8ea2-9707fc99294a, content: 'Less well-preserved remains of the sauropodomorphs Jaklapallisaurus and Nambalia , along with the ea...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 41, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Origins and early evolution'}),
#  Document(id=dd3df00f-0f83-41dc-a61b-f6e56d967944, content: 'When dinosaurs appeared, they were not the dominant terrestrial animals. The terrestrial habitats we...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 42, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Origins and early evolution'}),
#  Document(id=300ccaaa-23ab-4a9a-a4af-8f8e634e3912, content: 'Dinosaur evolution after the Triassic followed changes in vegetation and the location of continents....', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 43, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Evolution and paleobiogeography'}),
#  Document(id=5021d333-99a2-467b-b6c9-a994a45a94fb, content: 'By the Early Cretaceous and the ongoing breakup of Pangaea, dinosaurs were becoming strongly differe...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 44, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Evolution and paleobiogeography'}),
#  Document(id=7c606b04-8db3-49d1-a82f-049fdb42ee35, content: 'There were three general dinosaur faunas in the Late Cretaceous. In the northern continents of North...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 45, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Evolution and paleobiogeography'}),
#  Document(id=5c237ce2-6ab0-42ea-b70b-e5f6039fc136, content: 'The Cretaceous–Paleogene extinction event, which occurred approximately 66 million years ago at the ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 46, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Evolution and paleobiogeography'}),
#  Document(id=5f1a8917-56b4-4fe7-8c97-74170d9423a5, content: 'The surviving lineages of neornithine birds, including the ancestors of modern ratites, ducks and ch...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 47, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Evolution and paleobiogeography'}),
#  Document(id=492ab3b9-e222-4ea9-9968-ed5dda0143bb, content: 'Dinosaurs belong to a group known as archosaurs, which also includes modern crocodilians. Within the...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 48, 'title': 'Dinosaurs', 'h2': 'Classification'}),
#  Document(id=96f29c45-9d5d-4ede-bacd-05d0d60e50de, content: 'Collectively, dinosaurs as a clade are divided into two primary branches, Saurischia and Ornithischi...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 49, 'title': 'Dinosaurs', 'h2': 'Classification'}),
#  Document(id=cde3495c-2c5f-4ac9-939f-321d326f99b7, content: 'By contrast, ornithischians—"bird-hipped", from the Greek ornitheios (ὀρνίθειος) meaning "of a bird"...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 50, 'title': 'Dinosaurs', 'h2': 'Classification'}),
#  Document(id=b5eee452-62e0-4b7b-bbda-614121351bbb, content: 'Despite the terms "bird hip" (Ornithischia) and "lizard hip" (Saurischia), birds are not part of Orn...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 51, 'title': 'Dinosaurs', 'h2': 'Classification'}),
#  Document(id=c3494554-a009-4732-9fb1-3dcd699db11d, content: 'The following is a simplified classification of dinosaur groups based on their evolutionary relation...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 52, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=1e9ca0d4-7ade-4966-bd3e-d494a5630311, content: 'Dinosauria', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 53, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=eadbda4e-2fe2-4955-9e16-15897fa0d11f, content: '†Ornithischia ("bird-hipped"; diverse bipedal and quadrupedal herbivores)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 54, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=65d3807f-8dee-4f85-9af8-6f6459ef53a0, content: '†Saphornithischia ("true" ornithischians)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 55, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=afdf6fc0-422f-4b42-8e55-e54e01ca7a8d, content: '†Heterodontosauridae (small herbivores/omnivores with prominent canine-like teeth)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 56, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=e787d75d-e621-4069-aebf-b8c33823d7e9, content: '†Genasauria ("cheeked lizards")', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 57, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=fa09a449-ba3e-45ab-9bdc-8ed4097e1a7e, content: '†Thyreophora (armored dinosaurs; bipeds and quadrupeds)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 58, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=fe859469-3055-4182-9fb6-48a9027cec17, content: '†Eurypoda (heavy, quadrupedal thyreophorans)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 59, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=419071b6-c2f5-4666-b24e-d628ba077c99, content: '†Stegosauria (spikes and plates as primary armor)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 60, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=c6a7abb0-8646-4c6a-9a3d-5eab844f12c6, content: '†Huayangosauridae (small stegosaurs with flank osteoderms and tail clubs)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 61, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=04ad39e2-f648-4857-aea3-e386de676845, content: '†Stegosauridae (large stegosaurs)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 62, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=3000cfcb-8e06-410b-b369-4f52f3c62ab5, content: '†Ankylosauria (scutes as primary armor)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 63, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=29ed0490-807b-4daa-bf53-aae47e1122d5, content: '†Parankylosauria (small, southern ankylosaurs with macuahuitl-like tails)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 64, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=58f79d0e-eaf1-4724-b4b4-6951f0d8bcf6, content: '†Nodosauridae (mostly spiky, club-less ankylosaurs)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 65, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=852e80a9-62a6-4e60-9b43-436c9b99dc85, content: '†Ankylosauridae (characterized by flat scutes)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 66, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=ae08d214-d607-4e06-89b6-6fa335c90280, content: '†Ankylosaurinae (club-tailed ankylosaurids)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 67, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=e8550829-c577-48c4-8b20-0598ff2ea77e, content: '†Neornithischia ("new ornithischians")', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 68, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=f8c87242-a8ef-4f0e-ab52-6d276d3968a3, content: '†Pyrodontia ("fire teeth")', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 69, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=338db0da-95b4-4b2b-bbb7-cdf76425c25d, content: '†Thescelosauridae ("wondrous lizards")', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 70, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=944cb0ad-70e7-4dcf-bf94-5a99cc3b76c0, content: '†Orodrominae (burrowers)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 71, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=233bf4c4-3ce2-4e40-a6f1-9a6dcb123944, content: '†Thescelosaurinae (large thescelosaurids)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 72, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=a1176279-525b-4daf-9032-9cb9bbd274a5, content: '†Cerapoda ("horned feet")', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 73, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=b1e1ac5b-5a6b-4ece-b990-a4e89d3eb2b3, content: '†Marginocephalia (characterized by a cranial growth)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 74, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=60cd6f42-2c28-4c37-bb98-8202db883e48, content: '†Pachycephalosauria (bipeds with domed or knobby growth on skulls)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 75, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=ca839c07-ac68-44d2-8007-0eaa610065fa, content: '†Ceratopsia (bipeds and quadrupeds; many had neck frills and horns)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 76, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=c5a277b8-537f-4741-a52e-f1322aeee1b9, content: '†Chaoyangsauridae (small, frill-less basal ceratopsians)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 77, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=a4f7e99d-0e37-46c0-adbe-1d70851553a9, content: '†Neoceratopsia ("new ceratopsians")', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 78, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=46c20f9a-fed1-4acb-af9d-65b75a7a70f4, content: '†Leptoceratopsidae (little to no frills, hornless, with robust jaws)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 79, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=be1a4526-1286-4543-b503-349ae679785e, content: '†Protoceratopsidae (basal ceratopsians with small frills and stubby horns)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 80, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=cbfa995f-eaee-40fe-88c1-18c193073fdb, content: '†Ceratopsoidea (large-horned ceratopsians)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 81, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=cfb1dce5-7e66-44be-884f-edb29b79a699, content: '†Ceratopsidae (large, elaborately ornamented ceratopsians)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 82, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=fa68940a-d061-4034-959f-73f140964609, content: '†Chasmosaurinae (ceratopsids with enlarged brow horns)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 83, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=575c5c6e-9e05-4a8c-9300-f9a99ff1e6fe, content: '†Centrosaurinae (ceratopsids mostly characterized by frill and nasal ornamentation)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 84, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=39ea252b-6e94-45b8-ba54-5dbc1dee3091, content: '†Nasutoceratopsini (centrosaurines with enlarged nasal cavities)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 85, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=f993dbbc-60cc-4cac-9260-95480db7d2e7, content: '†Centrosaurini (centrosaurines with enlarged nasal horns)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 86, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=3f6f34b9-30ac-4504-b90e-e556a15a0401, content: '†Pachyrhinosaurini (mostly had nasal bosses instead of horns)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 87, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=7e594f0d-7f80-49f6-990a-016b73f96f57, content: '†Ornithopoda (various sizes; bipeds and quadrupeds; evolved a method of chewing using skull flexibil...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 88, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=cc4a1828-4a92-44a6-bc4a-e41dbcc3f089, content: '†Hypsilophodontidae (small European neornithischians)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 89, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=e8d83cc2-c81d-4e25-b95f-b61fb93aca8f, content: '†Iguanodontia ("iguana teeth"; advanced ornithopods)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 90, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=d0b69bd9-fc85-4015-bcbd-36b80c5ee362, content: '†Rhabdodontomorpha (with distinctive dentition)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 91, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=c4ab9aa8-5197-4988-840b-48ef8766d51f, content: '†Tenontosauridae (North American rhabdodontomorphs; bipeds and quadrupeds)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 92, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=c807513b-9986-4443-8a1e-71387e10484f, content: '†Rhabdodontidae (European rhabdodontomorphs)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 93, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=4d24c2a3-48a6-460f-9639-b1fd1d9b9905, content: '†Euiguanodontia ("true iguanodonts")', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 94, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=64029d15-5bb9-4d66-a048-16931a45c09c, content: '†Elasmaria (mostly southern ornithopods with mineralized plates along the ribs; may be thescelosauri...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 95, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=535882b5-41a5-4876-aa30-8e919fc9a73c, content: '†Dryomorpha ( Dryosaurus and more advanced ornithopods)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 96, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=6ed3b3b7-b403-4448-8b3f-1840834c1bb6, content: '†Dryosauridae (mid-sized, small headed)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 97, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=eef14deb-635a-4d57-ab50-871ad840d2a0, content: '†Ankylopollexia (early members mid-sized, stocky)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 98, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=1b937f43-3ff9-45f5-b543-473503369653, content: '†Styracosterna ("spiked sterna")', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 99, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=1c461f1f-fe96-4c44-90c5-2de30d2fe01e, content: '†Hadrosauriformes (ancestrally had a thumb spike; large quadrupedal herbivores, with teeth merged in...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 100, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=c45a484e-06d3-434d-9379-0fe3cd9c2e34, content: '†Hadrosauromorpha (hadrosaurids and their closest relatives)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 101, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=9fb67dde-5b72-4d19-9060-b6ca4ce201ec, content: '†Hadrosauridae ("duck-billed dinosaurs"; often with crests)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 102, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=07cd519f-6f12-4b80-9c91-77cd3e68ef14, content: '†Saurolophinae (hadrosaurids with solid, small, no crests)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 103, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=1f840b45-01d7-4ab4-92a3-cf1c1e6f01e9, content: '†Brachylophosaurini (short-crested)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 104, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=9cbf7f56-9056-4865-92c7-2069bf75d4d6, content: '†Kritosaurini (enlarged, solid nasal crests)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 105, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=d62ea16b-bb0b-43a7-8a78-60025c5f6462, content: '†Saurolophini (small, spike-like crests)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 106, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=2863caff-2dab-4b16-bb7e-3a13c421ff08, content: '†Edmontosaurini (flat-headed saurolophines)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 107, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=4d4920f6-c5ce-4065-9e5e-882a71f6998e, content: '†Lambeosaurinae (hadrosaurids often with hollow crests)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 108, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=a15b5f41-a6e7-4ee9-9ae5-5d816b07edc2, content: '†Aralosaurini (solid-crested)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 109, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=dd866227-2500-40ed-abf6-3f05956e9cdf, content: '†Tsintaosaurini (vertical, tube-like crests)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 110, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=5e02a38d-4534-4fab-9b91-375c64b0179f, content: '†Parasaurolophini (long, backwards-arcing crests)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 111, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=36a05e2f-3d6d-4968-818e-4fe6195db03e, content: '†Lambeosaurini (usually rounded crests)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 112, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=873b1c9c-faea-4df9-a8a5-fbb0e50b24ee, content: 'Saurischia', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 113, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=7450dafd-88e2-4d92-b009-9c2c8bc73e4a, content: '†Herrerasauridae (early bipedal carnivores)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 114, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=03cb4882-7874-4642-bbd9-9e9519be94bc, content: '†Sauropodomorpha (herbivores with small heads, long necks, and long tails)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 115, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=a7557d64-dfdc-4294-9c79-9f2ed02c5007, content: '†Unaysauridae (primitive, strictly bipedal "prosauropods")', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 116, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=79111fea-77f4-4b06-895d-a35ea961e342, content: '†Plateosauria (diverse; bipeds and quadrupeds)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 117, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=99f67804-9b2a-4856-a4b0-3e0e95773d01, content: '†Massopoda ("heavy feet")', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 118, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=3c1fc5dd-73d2-4f3a-9c21-266e59ab68cb, content: '†Massospondylidae (long-necked, primitive sauropodomorphs)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 119, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=aae321f9-d183-48cf-a472-efab75e081f7, content: '†Riojasauridae (large, primitive sauropodomorphs)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 120, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=3a6d0553-7f70-47ba-ac0b-60bca7720b1a, content: '†Sauropodiformes (heavy, bipeds and quadrupeds)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 121, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=b77ddca6-5602-4d0a-a0a5-01cf177fe8e0, content: '†Sauropoda (very large and heavy; quadrupedal)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 122, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=5725b65f-71cb-4f5d-9fe5-41ac3464ee16, content: '†Lessemsauridae (gigantic yet lacking several weight-saving adaptations)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 123, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=5fc9781a-40fd-4a8f-a643-acfe4fffecab, content: '†Gravisauria ("heavy lizards")', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 124, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=c33b73f3-7cdc-4814-a201-ead7c351bfc1, content: '†Eusauropoda ("true sauropods")', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 125, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=14864bd7-52fe-46f3-9846-6e7326a22b97, content: '†Turiasauria (often large, widespread sauropods)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 126, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=f7efc5f4-6c33-4306-a82a-e92addff461e, content: '†Neosauropoda ("new sauropods"; columnar limbs)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 127, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=e7731436-30b2-406d-a33d-67ae148a450c, content: '†Diplodocoidea (skulls and tails elongated; teeth typically narrow and pencil-like)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 128, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=a0e78323-ac85-4593-a354-4bb336725565, content: '†Rebbachisauridae (short-necked, low-browsing diplodocoids often with high backs)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 129, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=250f7b3b-4b1c-47eb-82b6-d59acd6a9c0a, content: '†Flagellicaudata (whip-tailed)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 130, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=57c8834e-85eb-44e0-947f-aa80dc24cb08, content: '†Dicraeosauridae (small, short-necked diplodocoids with enlarged cervical and dorsal vertebrae)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 131, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=e50bf3ca-330b-4f96-bb57-cd967a3bd793, content: '†Diplodocidae (extremely long-necked)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 132, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=e282b9d3-d199-4a0d-8697-f8ebcb7bcb46, content: '†Apatosaurinae (robust cervical vertebrae)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 133, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=0aa228d8-52f4-4445-aeb5-63ef635a5b86, content: '†Diplodocinae (long, thin necks)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 134, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=e68c80c5-14f6-47fd-a70b-887efd863639, content: '†Macronaria (boxy skulls; spoon- or pencil-shaped teeth)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 135, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=5bc7f01d-a87a-4e97-85a8-95597811471f, content: '†Titanosauriformes ("titan lizard forms")', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 136, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=82ede8c7-4f0a-430b-92ad-9ae2c9fe0954, content: '†Brachiosauridae (long-necked, long-armed macronarians)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 137, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=e72b3bb1-c491-41b8-a3fc-c84d61f39f30, content: '†Somphospondyli ("porous vertebrae")', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 138, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=f4f6988f-905d-47b7-8bcf-e33211b4567e, content: '†Euhelopodidae (stocky, mostly Asian)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 139, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=d7f12ed4-db30-43cb-a99b-093ab091cb2e, content: '†Diamantinasauria (horse-like skulls; restricted to the Southern Hemisphere; may be titanosaurs)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 140, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=136bd8b9-1711-4225-bafb-0fc885854c0f, content: '†Titanosauria (diverse; stocky, with wide hips; most common in the Late Cretaceous of southern conti...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 141, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=1a2a3713-05a2-4ec2-9a4e-6c4c3910224b, content: 'Theropoda (carnivorous)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 142, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=876807ce-c8ae-427a-b4b6-c90eb7490964, content: 'Neotheropoda ("new theropods")', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 143, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=3aa1f14a-a970-4128-a875-c60278aacd87, content: '†Coelophysoidea (early theropods; includes Coelophysis and close relatives)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 144, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=cbf4c066-d407-4b71-b499-13923eb1d998, content: '†"Dilophosaur-grade neotheropods" (larger kink-snouted dinosaurs)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 145, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=578e1dbc-d46d-45c6-b524-6a99143f8ce3, content: 'Averostra ("bird snouts")', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 146, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=30c568d5-7875-43f9-b1e4-88b1ee9f3161, content: '†Ceratosauria (generally elaborately horned carnivores that existed from the Jurassic to Cretaceous ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 147, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=459da124-d2f4-4142-ac25-c2d2dfd93d97, content: '†Ceratosauridae (ceratosaurs with large teeth)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 148, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=ec6b0461-231c-4e5b-8543-6f3a4349a185, content: '†Abelisauroidea (ceratosaurs exemplified by reduced arms and hands)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 149, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=670c82eb-c6cf-4446-8f65-a465f4f4c302, content: '†Abelisauridae (large abelisauroids with short arms and oftentimes elaborate facial ornamentation)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 150, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=6f93bb6d-d75c-428a-8dbd-fe7a1f9ebeb0, content: '†Noasauridae (diverse, generally light theropods; may include several obscure taxa)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 151, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=5f5a6ef6-5745-4d5e-89d2-307b49b48057, content: '†Elaphrosaurinae (bird-like; omnivorous as juveniles but herbivorous as adults)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 152, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#  Document(id=bf78df79-4661-49bd-b7e8-f1211bda87f5, content: '†Noasaurinae (small carnivores)', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 153, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
# ...
#  Document(id=6bb0a85e-82e8-46f7-bd59-f2dec22a4255, content: 'From a behavioral standpoint, one of the most valuable dinosaur fossils was discovered in the Gobi D...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 209, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Behavior'}),
#  Document(id=b45c8281-3e51-41d3-9989-a1071a4cf426, content: 'Comparisons between the scleral rings of dinosaurs and modern birds and reptiles have been used to i...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 210, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Behavior'}),
#  Document(id=8e3b7de3-4fb0-45c4-a576-e621a5d2be91, content: 'Based on fossil evidence from dinosaurs such as Oryctodromeus , some ornithischian species seem to h...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 211, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Behavior'}),
#  Document(id=33b0f6a8-71a7-481a-89e2-aa51ce41d06d, content: 'Modern birds communicate by visual and auditory signals, and the wide diversity of visual display st...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 212, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Communication'}),
#  Document(id=2d0d3c7c-e6a6-404a-bdbe-94e9acfe221d, content: 'On the basis that non-avian dinosaurs did not have syrinxes and that their next close living relativ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 213, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Communication'}),
#  Document(id=69e476bc-1227-458e-b4cf-c46946909174, content: 'In 2023, a fossilized larynx was described, from a specimen of the ankylosaurid Pinacosaurus . The s...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 214, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Communication'}),
#  Document(id=76b9b0cb-74a1-4f52-89ed-127cf0a4a592, content: 'All dinosaurs laid amniotic eggs. Dinosaur eggs were usually laid in a nest. Most species create som...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 215, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Reproductive biology'}),
#  Document(id=7202bc90-01e0-4dbd-8ce5-d3fe188b9cec, content: 'When laying eggs, females grow a special type of bone between the hard outer bone and the marrow of ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 216, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Reproductive biology'}),
#  Document(id=41134eba-4fc2-4fbb-b649-03d2f30f9a3d, content: 'Another widespread trait among modern birds (but see below in regards to fossil groups and extant me...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 217, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Reproductive biology'}),
#  Document(id=cc42eeab-0e26-440f-9a13-68f14583e327, content: 'However, there is ample evidence of precociality or superprecociality among many dinosaur species, p...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 218, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Reproductive biology'}),
#  Document(id=7e2b876e-e117-4201-9699-05ffc105ce88, content: 'Genital structures are unlikely to fossilize as they lack scales that may allow preservation via pig...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 219, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Reproductive biology'}),
#  Document(id=4cf9c1c5-d224-431e-a325-13edb6a5b876, content: 'Because both modern crocodilians and birds have four-chambered hearts (albeit modified in crocodilia...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 220, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Physiology'}),
#  Document(id=65a756e8-b157-4dad-aee8-c303e59eeb88, content: 'After non-avian dinosaurs were discovered, paleontologists first posited that they were ectothermic....', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 221, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Physiology'}),
#  Document(id=21851dff-848f-436f-b647-73a8f9c768cd, content: 'One of the greatest contributions to the modern understanding of dinosaur physiology has been paleoh...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 222, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Physiology'}),
#  Document(id=38747650-2a2e-4d7a-891e-39cf13cde837, content: 'In saurischian dinosaurs, higher metabolisms were supported by the evolution of the avian respirator...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 223, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Physiology'}),
#  Document(id=344f3db0-4902-4f13-9b83-1ac317291fef, content: 'Like other reptiles, dinosaurs are primarily uricotelic, that is, their kidneys extract nitrogenous ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 224, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Physiology'}),
#  Document(id=ffa9301b-ef21-4e8e-9c61-2415d4dc2a46, content: 'The size and shape of the brain can be partly reconstructed based on the surrounding bones. In 1896,...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 225, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Physiology'}),
#  Document(id=6c11bf6a-1c84-4995-8df7-6da8c40350db, content: 'The possibility that dinosaurs were the ancestors of birds was first suggested in 1868 by Thomas Hen...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 226, 'title': 'Dinosaurs', 'h2': 'Origin of birds'}),
#  Document(id=34bc5b51-961f-4ad7-af4f-d210d8ea09db, content: 'Feathers are one of the most recognizable characteristics of modern birds, and a trait that was also...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 227, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Feathers'}),
#  Document(id=d475b10d-8521-4f4b-aedc-7ddbebe5afe3, content: 'However, researchers do not agree regarding whether these structures share a common origin between l...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 228, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Feathers'}),
#  Document(id=6528daf5-cd31-4f0f-adc0-718d54c1a4c8, content: 'Archaeopteryx was the first fossil found that revealed a potential connection between dinosaurs and ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 229, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Feathers'}),
#  Document(id=9acbde84-ec0d-42f2-bd1c-a6c9280c97cb, content: 'Because feathers are often associated with birds, feathered dinosaurs are often touted as the missin...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 230, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Skeleton'}),
#  Document(id=88e9ee57-65bf-457e-8fe3-b5c61cc64ab9, content: 'Large meat-eating dinosaurs had a complex system of air sacs similar to those found in modern birds,...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 231, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Soft anatomy'}),
#  Document(id=1304da6f-673b-4d6d-a31d-d426eeaa4a07, content: 'Fossils of the troodonts Mei and Sinornithoides demonstrate that some dinosaurs slept with their hea...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 232, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Behavioral evidence'}),
#  Document(id=f99cb7f0-52a2-4d11-b3c3-230836106461, content: 'Some dinosaurs are known to have used gizzard stones like modern birds. These stones are swallowed b...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 233, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Behavioral evidence'}),
#  Document(id=925e2e40-abfa-4de0-84b0-5ed43aaae795, content: 'All non-avian dinosaurs and most lineages of birds became extinct in a mass extinction event, called...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 234, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups'}),
#  Document(id=0a2497c5-67a0-4a55-8a4e-d3e562d50490, content: 'Just before the K-Pg extinction event, the number of non-avian dinosaur species that existed globall...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 235, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Pre-extinction diversity'}),
#  Document(id=be4485dc-42cb-49ae-8fa2-80e4a7a2f61b, content: 'The bolide impact hypothesis, first brought to wide attention in 1980 by Walter Alvarez, Luis Alvare...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 236, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Impact event'}),
#  Document(id=629416ab-5186-4dc1-9357-d3c3845e7fbb, content: 'Within hours, the Chicxulub impact would have created immediate effects such as earthquakes, tsunami...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 237, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Impact event'}),
#  Document(id=61a7b117-fd0d-4ced-afd8-6a5dfc731370, content: 'At the time of the K-Pg extinction, the Deccan Traps flood basalts of India were actively erupting. ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 238, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Deccan Traps'}),
#  Document(id=1dc1c541-8d19-46cc-a8a8-4c9fb754d19e, content: 'Before 2000, arguments that the Deccan Traps eruptions—as opposed to the Chicxulub impact—caused the...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 239, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Deccan Traps'}),
#  Document(id=848618ee-4a45-4de2-96d9-6d712e45ab62, content: 'Whether the Deccan Traps were a major cause of the extinction, on par with the Chicxulub impact, rem...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 240, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Deccan Traps'}),
#  Document(id=bdcc79e6-07e0-49bb-afb6-d26d50dd157e, content: 'Non-avian dinosaur remains have occasionally been found above the K-Pg boundary. In 2000, Spencer Lu...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 241, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Possible Paleocene survivors'}),
#  Document(id=c3383ad0-dfc3-4c1f-bf7b-b226d08d7c5a, content: 'By human standards, dinosaurs were creatures of fantastic appearance and often enormous size. As suc...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 242, 'title': 'Dinosaurs', 'h2': 'Cultural depictions'}),
#  Document(id=91813102-3a53-4d25-a599-c684c283f26a, content: 'Public enthusiasm for dinosaurs first developed in Victorian England, where in 1854, three decades a...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 243, 'title': 'Dinosaurs', 'h2': 'Cultural depictions'}),
#  Document(id=8b1e2819-0143-4c72-9645-6c63257a9bba, content: 'The popular preoccupation with dinosaurs has ensured their appearance in literature, film, and other...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 244, 'title': 'Dinosaurs', 'h2': 'Cultural depictions'}),
#  Document(id=b3be6bc7-27ad-4d61-962d-c3f020605272, content: 'Dinosaur diet and feeding', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 245, 'title': 'Dinosaurs', 'h2': 'See also'}),
#  Document(id=e74a6b47-f618-4620-bf67-eba711f74523, content: 'Evolutionary history of life', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 246, 'title': 'Dinosaurs', 'h2': 'See also'}),
#  Document(id=81dafff2-ed52-4852-b529-c1942be5d9f1, content: 'Lists of dinosaur-bearing stratigraphic units', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 247, 'title': 'Dinosaurs', 'h2': 'See also'}),
#  Document(id=8d2ddb5f-282f-43af-82d6-2c05f1130acb, content: 'List of dinosaur genera', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 248, 'title': 'Dinosaurs', 'h2': 'See also'}),
#  Document(id=a0dfade0-0c98-442e-b979-abb8a78bfba8, content: 'List of bird genera', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 249, 'title': 'Dinosaurs', 'h2': 'See also'}),
#  Document(id=712efb60-41ee-4bdb-80e3-58b9d2303b74, content: 'List of birds', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 250, 'title': 'Dinosaurs', 'h2': 'See also'}),
#  Document(id=aad43dfa-f9e0-442b-93ba-9adacfa087ee, content: 'List of informally named dinosaurs', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 251, 'title': 'Dinosaurs', 'h2': 'See also'}),
#  Document(id=6f42ea0b-4fe0-48cc-88a6-fb1d4ee9af0d, content: 'List of films featuring dinosaurs', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 252, 'title': 'Dinosaurs', 'h2': 'See also'}),
#  Document(id=2920c0ef-4cd9-47e1-a9b4-e3b1ca58027a, content: 'University of Southampton (September 29, 2021). "Two New Species of Large Predatory Dinosaur With Cr...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 253, 'title': 'Dinosaurs', 'h2': 'Further reading'}),
#  Document(id=6cd74530-5f09-4abc-968e-405363ce54af, content: 'Zhou, Zhonghe (October 2004). "The origin and early evolution of birds: discoveries, disputes, and p...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 254, 'title': 'Dinosaurs', 'h2': 'Further reading'}),
#  Document(id=aed3e520-09e1-49a1-a764-9b0fcf1f06fb, content: 'Paul, Gregory S. (2002). Dinosaurs of the Air: The Evolution and Loss of Flight in Dinosaurs and Bir...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 255, 'title': 'Dinosaurs', 'h2': 'Further reading'}),
#  Document(id=5e6cf205-8b04-4777-8199-3ffb51d8d17b, content: 'Stewart, Tabori & Chang (1997). The Humongous Book of Dinosaurs . New York: Stewart, Tabori & Chang....', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 256, 'title': 'Dinosaurs', 'h2': 'Further reading'}),
#  Document(id=808e9727-da70-4044-8c27-53b93a25e12c, content: 'Sternberg, Charles Mortram (1966) [Original edition published by E. Cloutier, printer to the King, 1...', meta: {'file_path': 'Dinosaur.html', 'source_id': '9236d65f-85a6-432a-867c-3bd9da3a578c', 'split_id': 257, 'title': 'Dinosaurs', 'h2': 'Further reading'})]

# %%
hierarchy = chunk_result["hierarchy"]

hierarchy
# Out:
# {'Dinosaur': {'title': 'Dinosaur',
#   'sections': [{'name': 'Definition',
#     'type': 'h2',
#     'chunks': [{'id': 'cb8a55b6-810a-4459-b2cf-93c07f41c9ec'},
#      {'id': '4d6d0694-1fe4-48c4-9379-01d826109ca6'},
#      {'id': 'a48cb64b-95ea-4800-bbd3-e1ef7727b215'}],
#     'sections': [{'name': 'General description',
#       'type': 'h3',
#       'chunks': [{'id': '0a920381-9ff3-4bd1-9b3c-632f0aa8ad29'},
#        {'id': '00833423-9899-4972-877d-3d7094c99e0a'},
#        {'id': 'd1009167-dd39-4144-9a61-eb7a99b22d41'}],
#       'sections': []},
#      {'name': 'Distinguishing anatomical features',
#       'type': 'h3',
#       'chunks': [{'id': '676bc8cb-b102-45a4-b833-33221443d915'},
#        {'id': 'fd9e37dc-1cec-40e4-9d6f-26cce1bc870c'},
#        {'id': 'e5dc260e-0162-405c-a77e-3d22f0d3a476'},
#        {'id': 'f8c8b75e-e34a-4625-8c56-c2ac8a0c4ce4'},
#        {'id': '2e1d8e4a-ed6e-4558-8f2a-1419aa5aae56'},
#        {'id': '74926ec4-9dd2-4165-a6f3-23333532ab53'},
#        {'id': 'e5eba7bf-ae55-4980-bca4-86cec1fc3ccb'},
#        {'id': 'c4fc6ffa-9ff9-4b2f-a603-9eb54b1105d7'},
#        {'id': 'd7550d1c-3281-45e3-8dad-bfc9b693f368'},
#        {'id': '04b48d44-acec-4242-9e11-3561f5c86f61'},
#        {'id': 'ace78762-890b-42db-a3c7-091e50cbb179'},
#        {'id': '68413975-a527-4740-bd40-96b18749d17a'},
#        {'id': '630c4cc2-5f23-4e74-a6f9-0db211e7965a'},
#        {'id': '1317ecdc-3dc7-4aab-b7dc-f66c3714992b'},
#        {'id': '64f8192c-d631-47c0-acbf-3ec54029f77f'},
#        {'id': '3c0fdc1b-94de-4f18-abf3-e706d74fad4d'},
#        {'id': '387ca0da-c3e3-49d3-96c7-9cf37509b4a2'}],
#       'sections': []}]},
#    {'name': 'History of study',
#     'type': 'h2',
#     'chunks': [],
#     'sections': [{'name': 'Pre-scientific history',
#       'type': 'h3',
#       'chunks': [{'id': '890b2d6a-d654-47a7-ba94-8ac1040d8f12'}],
#       'sections': []},
#      {'name': 'Early dinosaur research',
#       'type': 'h3',
#       'chunks': [{'id': '283e224c-7db4-4fa3-903d-08d863d2dffb'},
#        {'id': 'dd3b2bd3-a32e-4f1f-a997-38e0bd273b12'},
#        {'id': 'ffa3b5c7-0a46-44f4-88c6-84d13aab913f'}],
#       'sections': []},
#      {'name': 'Discoveries in North America',
#       'type': 'h3',
#       'chunks': [{'id': 'c360c1b6-02f6-4662-8ec7-806409ab48ef'},
#        {'id': 'd7028bee-ca3f-4270-9b5f-fcb5fcfaef7f'}],
#       'sections': []},
#      {'name': '"Dinosaur renaissance" and beyond',
#       'type': 'h3',
#       'chunks': [{'id': '41b82a2f-147f-4319-aded-28df5d5eb78d'},
#        {'id': '5500ee58-98e8-4c4c-b055-9c2e0a8452b0'},
#        {'id': '09ca21f8-4980-4d92-98a2-a13cf4e9e382'}],
#       'sections': []},
#      {'name': 'Soft tissue and molecular preservation',
#       'type': 'h3',
#       'chunks': [{'id': '1a5e9256-9726-422e-9ecc-b3548be65af0'},
#        {'id': 'fc0fc126-2f79-44b8-bbc3-825f93e56bd1'},
#        {'id': '020c93c6-c105-47d7-8fbe-3dc5cbe72b88'}],
#       'sections': []}]},
#    {'name': 'Evolutionary history',
#     'type': 'h2',
#     'chunks': [],
#     'sections': [{'name': 'Origins and early evolution',
#       'type': 'h3',
#       'chunks': [{'id': '11992020-3225-4ff7-b763-1f8e0b0de756'},
#        {'id': 'a63c7f71-b749-455e-a5be-897bd7077454'},
#        {'id': '794fb096-a8dc-4196-8ea2-9707fc99294a'},
#        {'id': 'dd3df00f-0f83-41dc-a61b-f6e56d967944'}],
#       'sections': []},
#      {'name': 'Evolution and paleobiogeography',
#       'type': 'h3',
#       'chunks': [{'id': '300ccaaa-23ab-4a9a-a4af-8f8e634e3912'},
#        {'id': '5021d333-99a2-467b-b6c9-a994a45a94fb'},
#        {'id': '7c606b04-8db3-49d1-a82f-049fdb42ee35'},
#        {'id': '5c237ce2-6ab0-42ea-b70b-e5f6039fc136'},
#        {'id': '5f1a8917-56b4-4fe7-8c97-74170d9423a5'}],
#       'sections': []}]},
#    {'name': 'Classification',
#     'type': 'h2',
#     'chunks': [{'id': '492ab3b9-e222-4ea9-9968-ed5dda0143bb'},
#      {'id': '96f29c45-9d5d-4ede-bacd-05d0d60e50de'},
#      {'id': 'cde3495c-2c5f-4ac9-939f-321d326f99b7'},
#      {'id': 'b5eee452-62e0-4b7b-bbda-614121351bbb'}],
#     'sections': [{'name': 'Taxonomy',
#       'type': 'h3',
#       'chunks': [{'id': 'c3494554-a009-4732-9fb1-3dcd699db11d'},
#        {'id': '1e9ca0d4-7ade-4966-bd3e-d494a5630311'},
#        {'id': 'eadbda4e-2fe2-4955-9e16-15897fa0d11f'},
#        {'id': '65d3807f-8dee-4f85-9af8-6f6459ef53a0'},
#        {'id': 'afdf6fc0-422f-4b42-8e55-e54e01ca7a8d'},
#        {'id': 'e787d75d-e621-4069-aebf-b8c33823d7e9'},
#        {'id': 'fa09a449-ba3e-45ab-9bdc-8ed4097e1a7e'},
#        {'id': 'fe859469-3055-4182-9fb6-48a9027cec17'},
#        {'id': '419071b6-c2f5-4666-b24e-d628ba077c99'},
#        {'id': 'c6a7abb0-8646-4c6a-9a3d-5eab844f12c6'},
#        {'id': '04ad39e2-f648-4857-aea3-e386de676845'},
#        {'id': '3000cfcb-8e06-410b-b369-4f52f3c62ab5'},
#        {'id': '29ed0490-807b-4daa-bf53-aae47e1122d5'},
#        {'id': '58f79d0e-eaf1-4724-b4b4-6951f0d8bcf6'},
#        {'id': '852e80a9-62a6-4e60-9b43-436c9b99dc85'},
#        {'id': 'ae08d214-d607-4e06-89b6-6fa335c90280'},
#        {'id': 'e8550829-c577-48c4-8b20-0598ff2ea77e'},
#        {'id': 'f8c87242-a8ef-4f0e-ab52-6d276d3968a3'},
#        {'id': '338db0da-95b4-4b2b-bbb7-cdf76425c25d'},
#        {'id': '944cb0ad-70e7-4dcf-bf94-5a99cc3b76c0'},
#        {'id': '233bf4c4-3ce2-4e40-a6f1-9a6dcb123944'},
#        {'id': 'a1176279-525b-4daf-9032-9cb9bbd274a5'},
#        {'id': 'b1e1ac5b-5a6b-4ece-b990-a4e89d3eb2b3'},
#        {'id': '60cd6f42-2c28-4c37-bb98-8202db883e48'},
#        {'id': 'ca839c07-ac68-44d2-8007-0eaa610065fa'},
#        {'id': 'c5a277b8-537f-4741-a52e-f1322aeee1b9'},
#        {'id': 'a4f7e99d-0e37-46c0-adbe-1d70851553a9'},
#        {'id': '46c20f9a-fed1-4acb-af9d-65b75a7a70f4'},
#        {'id': 'be1a4526-1286-4543-b503-349ae679785e'},
#        {'id': 'cbfa995f-eaee-40fe-88c1-18c193073fdb'},
#        {'id': 'cfb1dce5-7e66-44be-884f-edb29b79a699'},
#        {'id': 'fa68940a-d061-4034-959f-73f140964609'},
#        {'id': '575c5c6e-9e05-4a8c-9300-f9a99ff1e6fe'},
#        {'id': '39ea252b-6e94-45b8-ba54-5dbc1dee3091'},
#        {'id': 'f993dbbc-60cc-4cac-9260-95480db7d2e7'},
#        {'id': '3f6f34b9-30ac-4504-b90e-e556a15a0401'},
#        {'id': '7e594f0d-7f80-49f6-990a-016b73f96f57'},
#        {'id': 'cc4a1828-4a92-44a6-bc4a-e41dbcc3f089'},
#        {'id': 'e8d83cc2-c81d-4e25-b95f-b61fb93aca8f'},
#        {'id': 'd0b69bd9-fc85-4015-bcbd-36b80c5ee362'},
#        {'id': 'c4ab9aa8-5197-4988-840b-48ef8766d51f'},
#        {'id': 'c807513b-9986-4443-8a1e-71387e10484f'},
#        {'id': '4d24c2a3-48a6-460f-9639-b1fd1d9b9905'},
#        {'id': '64029d15-5bb9-4d66-a048-16931a45c09c'},
#        {'id': '535882b5-41a5-4876-aa30-8e919fc9a73c'},
#        {'id': '6ed3b3b7-b403-4448-8b3f-1840834c1bb6'},
#        {'id': 'eef14deb-635a-4d57-ab50-871ad840d2a0'},
#        {'id': '1b937f43-3ff9-45f5-b543-473503369653'},
#        {'id': '1c461f1f-fe96-4c44-90c5-2de30d2fe01e'},
#        {'id': 'c45a484e-06d3-434d-9379-0fe3cd9c2e34'},
#        {'id': '9fb67dde-5b72-4d19-9060-b6ca4ce201ec'},
#        {'id': '07cd519f-6f12-4b80-9c91-77cd3e68ef14'},
#        {'id': '1f840b45-01d7-4ab4-92a3-cf1c1e6f01e9'},
#        {'id': '9cbf7f56-9056-4865-92c7-2069bf75d4d6'},
#        {'id': 'd62ea16b-bb0b-43a7-8a78-60025c5f6462'},
#        {'id': '2863caff-2dab-4b16-bb7e-3a13c421ff08'},
#        {'id': '4d4920f6-c5ce-4065-9e5e-882a71f6998e'},
#        {'id': 'a15b5f41-a6e7-4ee9-9ae5-5d816b07edc2'},
#        {'id': 'dd866227-2500-40ed-abf6-3f05956e9cdf'},
#        {'id': '5e02a38d-4534-4fab-9b91-375c64b0179f'},
#        {'id': '36a05e2f-3d6d-4968-818e-4fe6195db03e'},
#        {'id': '873b1c9c-faea-4df9-a8a5-fbb0e50b24ee'},
#        {'id': '7450dafd-88e2-4d92-b009-9c2c8bc73e4a'},
#        {'id': '03cb4882-7874-4642-bbd9-9e9519be94bc'},
#        {'id': 'a7557d64-dfdc-4294-9c79-9f2ed02c5007'},
#        {'id': '79111fea-77f4-4b06-895d-a35ea961e342'},
#        {'id': '99f67804-9b2a-4856-a4b0-3e0e95773d01'},
#        {'id': '3c1fc5dd-73d2-4f3a-9c21-266e59ab68cb'},
#        {'id': 'aae321f9-d183-48cf-a472-efab75e081f7'},
#        {'id': '3a6d0553-7f70-47ba-ac0b-60bca7720b1a'},
#        {'id': 'b77ddca6-5602-4d0a-a0a5-01cf177fe8e0'},
#        {'id': '5725b65f-71cb-4f5d-9fe5-41ac3464ee16'},
#        {'id': '5fc9781a-40fd-4a8f-a643-acfe4fffecab'},
#        {'id': 'c33b73f3-7cdc-4814-a201-ead7c351bfc1'},
#        {'id': '14864bd7-52fe-46f3-9846-6e7326a22b97'},
#        {'id': 'f7efc5f4-6c33-4306-a82a-e92addff461e'},
#        {'id': 'e7731436-30b2-406d-a33d-67ae148a450c'},
#        {'id': 'a0e78323-ac85-4593-a354-4bb336725565'},
#        {'id': '250f7b3b-4b1c-47eb-82b6-d59acd6a9c0a'},
#        {'id': '57c8834e-85eb-44e0-947f-aa80dc24cb08'},
#        {'id': 'e50bf3ca-330b-4f96-bb57-cd967a3bd793'},
#        {'id': 'e282b9d3-d199-4a0d-8697-f8ebcb7bcb46'},
#        {'id': '0aa228d8-52f4-4445-aeb5-63ef635a5b86'},
#        {'id': 'e68c80c5-14f6-47fd-a70b-887efd863639'},
#        {'id': '5bc7f01d-a87a-4e97-85a8-95597811471f'},
#        {'id': '82ede8c7-4f0a-430b-92ad-9ae2c9fe0954'},
#        {'id': 'e72b3bb1-c491-41b8-a3fc-c84d61f39f30'},
#        {'id': 'f4f6988f-905d-47b7-8bcf-e33211b4567e'},
#        {'id': 'd7f12ed4-db30-43cb-a99b-093ab091cb2e'},
#        {'id': '136bd8b9-1711-4225-bafb-0fc885854c0f'},
#        {'id': '1a2a3713-05a2-4ec2-9a4e-6c4c3910224b'},
#        {'id': '876807ce-c8ae-427a-b4b6-c90eb7490964'},
#        {'id': '3aa1f14a-a970-4128-a875-c60278aacd87'},
#        {'id': 'cbf4c066-d407-4b71-b499-13923eb1d998'},
#        {'id': '578e1dbc-d46d-45c6-b524-6a99143f8ce3'},
#        {'id': '30c568d5-7875-43f9-b1e4-88b1ee9f3161'},
#        {'id': '459da124-d2f4-4142-ac25-c2d2dfd93d97'},
#        {'id': 'ec6b0461-231c-4e5b-8543-6f3a4349a185'},
#        {'id': '670c82eb-c6cf-4446-8f65-a465f4f4c302'},
#        {'id': '6f93bb6d-d75c-428a-8dbd-fe7a1f9ebeb0'},
#        {'id': '5f5a6ef6-5745-4d5e-89d2-307b49b48057'},
#        {'id': 'bf78df79-4661-49bd-b7e8-f1211bda87f5'},
#        {'id': '3e72d85a-9655-4938-8ea8-bb40aa768171'},
#        {'id': 'f950c30b-dbc4-4288-9715-358a767b9c34'},
#        {'id': '19c3b158-3879-4572-8d70-9189f4ba57b7'},
#        {'id': '33485a3f-852a-4b88-8c57-2d0158341bb6'},
#        {'id': 'cb80f7a0-970c-416c-8d40-bc12a79f3ba5'},
#        {'id': '5ffe8ad6-7f3f-4446-b7bf-8c65f44855e1'},
#        {'id': '6c947448-9d31-40c9-b4cd-91a487243b5d'},
#        {'id': '01d9abcd-99f3-45fd-96cc-5b0cfd943563'},
#        {'id': 'ac6459c6-6ccd-4484-aa33-dfff66921929'},
#        {'id': '056e05ca-578a-4267-9f32-e87b1b7c0c99'},
#        {'id': '707fd20a-3d95-4c45-8a1c-e3a449e521b3'},
#        {'id': '2725ab90-901d-4041-a37f-e6dfa9978cb7'},
#        {'id': '349355cb-1407-4e51-8869-70f0e4334b60'},
#        {'id': '85e8bfe3-70bd-4b7c-915e-4c295a442d06'},
#        {'id': '1e3e82a6-92ca-44ee-bc99-cc87f66ec41a'},
#        {'id': '5b242dd1-d5c3-491c-a22a-f7d1dce7f028'},
#        {'id': '4b4c60fc-a333-4353-bbf3-da81ded8029d'},
#        {'id': '75662e8b-0a3e-49e8-8daa-d84a6569f35b'},
#        {'id': 'e4b1f9aa-7283-4aa3-924e-42cb760d7344'},
#        {'id': 'e8055f71-3279-440a-80cb-9520a666b19d'},
#        {'id': '9fa23c37-f6ef-474b-be47-8b7152ba6bc9'},
#        {'id': '45c81ec5-ead6-47ee-9da7-a2a3918857b6'},
#        {'id': '1917a790-4a61-495c-930c-2a5f628dc009'},
#        {'id': '69f37343-6b11-42f2-bfd2-1cd2d3a85b77'},
#        {'id': 'c426aa17-1a64-4acb-8604-c4843060ddda'},
#        {'id': '5c04bf22-b18c-4dd0-80a9-8be6fd17bac4'},
#        {'id': '509e6ea7-dd33-431e-9167-3ae8f42a2404'},
#        {'id': '56416beb-8dcf-4aec-9b10-4f45cd1f2d19'},
#        {'id': 'af10a688-23f8-4125-af1f-8fd195438a8c'},
#        {'id': '5967cf8e-5cdf-49e1-bd75-6a6d0e1ae602'},
#        {'id': 'f95202b2-b371-4973-8325-3f88d8536adb'},
#        {'id': 'be3a41b1-f16b-4c88-9d68-590367693f0a'},
#        {'id': 'f1a393ed-dbf4-4657-972e-e82c2f1b4a4d'},
#        {'id': '109e7873-1d73-4d18-949b-87c2eb696a18'},
#        {'id': 'd47c3b93-acd4-4242-94c6-a6912f893592'},
#        {'id': '10b36b0d-e96d-4d67-82e4-3df5283c6829'},
#        {'id': 'f676a0fc-6c8b-496c-9f53-bd448eecf26e'},
#        {'id': '6e10c311-ea86-4eab-9673-daa44cef4848'},
#        {'id': 'df60e4cc-2caa-461a-82c2-45326cc195fb'},
#        {'id': '4fcb99bc-1a38-4afb-8b87-2742164fada5'},
#        {'id': '5f788cef-8bf2-4274-912c-a714228d765b'},
#        {'id': '30d0c8e9-f080-4e54-8e0a-11fd04d66e04'},
#        {'id': '050e5e5b-47c5-4dce-850a-cb0694dc6c86'}],
#       'sections': []},
#      {'name': 'Timeline of major groups',
#       'type': 'h3',
#       'chunks': [{'id': '8d62db7c-e005-4c48-b082-b84b72e54f88'}],
#       'sections': []}]},
#    {'name': 'Paleobiology',
#     'type': 'h2',
#     'chunks': [{'id': 'b46be2c5-1d98-4616-8812-7ef01f24d20a'}],
#     'sections': [{'name': 'Size',
#       'type': 'h3',
#       'chunks': [{'id': 'ec1e715d-86d4-4274-9bb7-997d38549248'},
#        {'id': '7fa8f46f-99e6-4a44-8119-a7519d39b208'}],
#       'sections': [{'name': 'Largest and smallest',
#         'type': 'h4',
#         'chunks': [{'id': '498ad21c-4a52-48f6-b4d6-a2edf359434d'},
#          {'id': '15cb93b6-cd4d-4084-9061-0747f039855f'},
#          {'id': 'bdc11382-1fb3-4235-8cda-d0acd97d7b84'},
#          {'id': 'd6e751cf-ab52-465e-942e-39ccc913d2cd'},
#          {'id': 'e33d9d1a-ffa5-410d-9f3d-135b7d048ca6'}],
#         'sections': []}]},
#      {'name': 'Behavior',
#       'type': 'h3',
#       'chunks': [{'id': '73108c87-7100-4875-a476-3567b7b6f6a6'},
#        {'id': 'f274fc43-70bb-47dc-b982-7e6c42380235'},
#        {'id': 'b56cb8f4-743e-4a97-b662-4f06306c8bc7'},
#        {'id': '6bb0a85e-82e8-46f7-bd59-f2dec22a4255'},
#        {'id': 'b45c8281-3e51-41d3-9989-a1071a4cf426'},
#        {'id': '8e3b7de3-4fb0-45c4-a576-e621a5d2be91'}],
#       'sections': []},
#      {'name': 'Communication',
#       'type': 'h3',
#       'chunks': [{'id': '33b0f6a8-71a7-481a-89e2-aa51ce41d06d'},
#        {'id': '2d0d3c7c-e6a6-404a-bdbe-94e9acfe221d'},
#        {'id': '69e476bc-1227-458e-b4cf-c46946909174'}],
#       'sections': []},
#      {'name': 'Reproductive biology',
#       'type': 'h3',
#       'chunks': [{'id': '76b9b0cb-74a1-4f52-89ed-127cf0a4a592'},
#        {'id': '7202bc90-01e0-4dbd-8ce5-d3fe188b9cec'},
#        {'id': '41134eba-4fc2-4fbb-b649-03d2f30f9a3d'},
#        {'id': 'cc42eeab-0e26-440f-9a13-68f14583e327'},
#        {'id': '7e2b876e-e117-4201-9699-05ffc105ce88'}],
#       'sections': []},
#      {'name': 'Physiology',
#       'type': 'h3',
#       'chunks': [{'id': '4cf9c1c5-d224-431e-a325-13edb6a5b876'},
#        {'id': '65a756e8-b157-4dad-aee8-c303e59eeb88'},
#        {'id': '21851dff-848f-436f-b647-73a8f9c768cd'},
#        {'id': '38747650-2a2e-4d7a-891e-39cf13cde837'},
#        {'id': '344f3db0-4902-4f13-9b83-1ac317291fef'},
#        {'id': 'ffa9301b-ef21-4e8e-9c61-2415d4dc2a46'}],
#       'sections': []}]},
#    {'name': 'Origin of birds',
#     'type': 'h2',
#     'chunks': [{'id': '6c11bf6a-1c84-4995-8df7-6da8c40350db'}],
#     'sections': [{'name': 'Feathers',
#       'type': 'h3',
#       'chunks': [{'id': '34bc5b51-961f-4ad7-af4f-d210d8ea09db'},
#        {'id': 'd475b10d-8521-4f4b-aedc-7ddbebe5afe3'},
#        {'id': '6528daf5-cd31-4f0f-adc0-718d54c1a4c8'}],
#       'sections': []},
#      {'name': 'Skeleton',
#       'type': 'h3',
#       'chunks': [{'id': '9acbde84-ec0d-42f2-bd1c-a6c9280c97cb'}],
#       'sections': []},
#      {'name': 'Soft anatomy',
#       'type': 'h3',
#       'chunks': [{'id': '88e9ee57-65bf-457e-8fe3-b5c61cc64ab9'}],
#       'sections': []},
#      {'name': 'Behavioral evidence',
#       'type': 'h3',
#       'chunks': [{'id': '1304da6f-673b-4d6d-a31d-d426eeaa4a07'},
#        {'id': 'f99cb7f0-52a2-4d11-b3c3-230836106461'}],
#       'sections': []}]},
#    {'name': 'Extinction of major groups',
#     'type': 'h2',
#     'chunks': [{'id': '925e2e40-abfa-4de0-84b0-5ed43aaae795'}],
#     'sections': [{'name': 'Pre-extinction diversity',
#       'type': 'h3',
#       'chunks': [{'id': '0a2497c5-67a0-4a55-8a4e-d3e562d50490'}],
#       'sections': []},
#      {'name': 'Impact event',
#       'type': 'h3',
#       'chunks': [{'id': 'be4485dc-42cb-49ae-8fa2-80e4a7a2f61b'},
#        {'id': '629416ab-5186-4dc1-9357-d3c3845e7fbb'}],
#       'sections': []},
#      {'name': 'Deccan Traps',
#       'type': 'h3',
#       'chunks': [{'id': '61a7b117-fd0d-4ced-afd8-6a5dfc731370'},
#        {'id': '1dc1c541-8d19-46cc-a8a8-4c9fb754d19e'},
#        {'id': '848618ee-4a45-4de2-96d9-6d712e45ab62'}],
#       'sections': []},
#      {'name': 'Possible Paleocene survivors',
#       'type': 'h3',
#       'chunks': [{'id': 'bdcc79e6-07e0-49bb-afb6-d26d50dd157e'}],
#       'sections': []}]},
#    {'name': 'Cultural depictions',
#     'type': 'h2',
#     'chunks': [{'id': 'c3383ad0-dfc3-4c1f-bf7b-b226d08d7c5a'},
#      {'id': '91813102-3a53-4d25-a599-c684c283f26a'},
#      {'id': '8b1e2819-0143-4c72-9645-6c63257a9bba'}],
#     'sections': []},
#    {'name': 'See also',
#     'type': 'h2',
#     'chunks': [{'id': 'b3be6bc7-27ad-4d61-962d-c3f020605272'},
#      {'id': 'e74a6b47-f618-4620-bf67-eba711f74523'},
#      {'id': '81dafff2-ed52-4852-b529-c1942be5d9f1'},
#      {'id': '8d2ddb5f-282f-43af-82d6-2c05f1130acb'},
#      {'id': 'a0dfade0-0c98-442e-b979-abb8a78bfba8'},
#      {'id': '712efb60-41ee-4bdb-80e3-58b9d2303b74'},
#      {'id': 'aad43dfa-f9e0-442b-93ba-9adacfa087ee'},
#      {'id': '6f42ea0b-4fe0-48cc-88a6-fb1d4ee9af0d'}],
#     'sections': []},
#    {'name': 'Notes', 'type': 'h2', 'chunks': [], 'sections': []},
#    {'name': 'References', 'type': 'h2', 'chunks': [], 'sections': []},
#    {'name': 'Bibliography', 'type': 'h2', 'chunks': [], 'sections': []},
#    {'name': 'Further reading',
#     'type': 'h2',
#     'chunks': [{'id': '2920c0ef-4cd9-47e1-a9b4-e3b1ca58027a'},
#      {'id': '6cd74530-5f09-4abc-968e-405363ce54af'},
#      {'id': 'aed3e520-09e1-49a1-a764-9b0fcf1f06fb'},
#      {'id': '5e6cf205-8b04-4777-8199-3ffb51d8d17b'},
#      {'id': '808e9727-da70-4044-8c27-53b93a25e12c'}],
#     'sections': []}],
#   'chunks': [{'id': '157fe7b1-3e3f-40dc-b7da-e6320557d55d'},
#    {'id': '0f9565ed-5f7c-4afa-baec-57d97ae8f1ed'},
#    {'id': '5f1d4df4-5f0e-4707-b231-c33398c1c639'},
#    {'id': 'd6ec0129-4cdc-489e-991c-82aa74016599'}]}}

# %% [markdown]
# Graph creator

# %% [markdown]
# Graph in Neo4j browser looks good!

# %% [markdown]
# Clean up: first chunk id not explicitly passed in hierarchy; while creating graph, mark first chunk in list as the first chunk

# %%
from neo4j import GraphDatabase

class Neo4jGraphCreator:
    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self.driver.close()

    def create_graph(self, page_dict):
        with self.driver.session() as session:
            # Create Page node with UUID
            page_uuid = str(uuid.uuid4())
            page_query = """
            MERGE (p:Page {title: $title})
            ON CREATE SET p.uuid = $uuid
            RETURN p
            """
            session.run(page_query, title=page_dict['title'], uuid=page_uuid)

            # Create sections and chunks
            self.create_sections_and_chunks(session, page_uuid, page_dict['sections'])
            self.create_chunks(session, page_uuid, page_dict['chunks'])

    def create_sections_and_chunks(self, session, parent_uuid, sections):
        for section in sections:
            section_uuid = str(uuid.uuid4())
            section_labels = f":Section:{section['type']}"
            
            # Query to find either Page or Section as parent
            section_query = f"""
            MATCH (parent {{uuid: $parent_uuid}})
            MERGE (s{section_labels} {{name: $name}})
            ON CREATE SET s.uuid = $uuid
            MERGE (parent)-[:HAS_SECTION]->(s)
            RETURN s
            """
            session.run(section_query, parent_uuid=parent_uuid, name=section['name'], uuid=section_uuid)

            # Recursively create sub-sections and chunks
            self.create_sections_and_chunks(session, section_uuid, section['sections'])
            self.create_chunks(session, section_uuid, section['chunks'])

    def create_chunks(self, session, parent_uuid, chunks):
        first_chunk_created = False
        
        for i, chunk in enumerate(chunks):
            # Use chunk['id'] as the UUID
            chunk_uuid = chunk['id']
            
            chunk_query = """
            MATCH (parent {uuid: $parent_uuid})
            MERGE (c:Chunk {uuid: $uuid})
            MERGE (parent)-[:HAS_CHUNK]->(c)
            RETURN c
            """
            session.run(chunk_query, parent_uuid=parent_uuid, uuid=chunk_uuid)

            # Create the FIRST_CHUNK relationship if first_chunk not yet created
            if not first_chunk_created and i == 0:
                first_chunk_query = """
                MATCH (parent {uuid: $parent_uuid}), (c:Chunk {uuid: $chunk_uuid})
                MERGE (parent)-[:FIRST_CHUNK]->(c)
                RETURN parent, c
                """
                session.run(first_chunk_query, parent_uuid=parent_uuid, chunk_uuid=chunk['id'])
                first_chunk_created = True

        # Create NEXT relationships between chunks once all chunks are created
        for i, chunk in enumerate(chunks):
            # Set the NEXT relationship
            if i < len(chunks) - 1:
                next_chunk_query = """
                MATCH (c1:Chunk {uuid: $uuid1}), (c2:Chunk {uuid: $uuid2})
                MERGE (c1)-[:NEXT]->(c2)
                RETURN c1, c2
                """
                session.run(next_chunk_query, uuid1=chunk['id'], uuid2=chunks[i + 1]['id'])



# neo4j_creator = Neo4jGraphCreator("bolt://localhost:7687", "neo4j", "neo4jpass")
# neo4j_creator.create_graph(hierarchy["Dinosaur"])
# neo4j_creator.close()

# %% [markdown]
# Cypher commands
#
# - Show graph:
#
# ```
# MATCH (n)-[r]->(m)
# RETURN n, r, m
# ```
#
# - Completely clean up graph
#
# ```
# MATCH (n)
# DETACH DELETE n
# ```

# %%
@component
class GraphCreatorComponent:
    """
    A component that creates a graph in Neo4j from the hierarchical structure of Wikipedia page chunks.
    """
    def run(self, hierarchy: dict):
        neo4j_creator = Neo4jGraphCreator("bolt://localhost:7687", "neo4j", "neo4jpass")
        neo4j_creator.create_graph(hierarchy["Dinosaur"])
        neo4j_creator.close()
        return {}

# %%
from pathlib import Path
from haystack.components.converters import TextFileToDocument
from haystack.components.embedders import OpenAIDocumentEmbedder
from haystack_integrations.document_stores.weaviate.document_store import WeaviateDocumentStore
from haystack.components.writers import DocumentWriter
from haystack import Pipeline
from haystack_integrations.document_stores.elasticsearch import ElasticsearchDocumentStore


converter = TextFileToDocument()
splitter = WikiPageChunker()
graph_creator = GraphCreatorComponent()

indexing_pipeline = Pipeline()

indexing_pipeline.add_component("converter", converter)
indexing_pipeline.add_component("splitter", splitter)
indexing_pipeline.add_component("graph_creator", graph_creator)

indexing_pipeline.connect("converter", "splitter")
indexing_pipeline.connect("splitter.hierarchy", "graph_creator.hierarchy")

indexing_pipeline.run(data={"converter": {"sources": [Path("Dinosaur.html")]}})
# Out:
# /home/kartikeya/miniconda3/envs/argonk/lib/python3.12/site-packages/posthog/client.py:345: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   timestamp = datetime.utcnow().replace(tzinfo=tzutc())
# /home/kartikeya/miniconda3/envs/argonk/lib/python3.12/site-packages/posthog/request.py:40: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   body["sentAt"] = datetime.utcnow().replace(tzinfo=tzutc()).isoformat()
# {'splitter': {'documents': [Document(id=a4263d5d-2898-42b0-9d5a-0ab0b28bddef, content: 'Dinosaurs are a diverse group of reptiles of the clade Dinosauria . They first appeared during the T...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 0, 'title': 'Dinosaurs'}),
#    Document(id=5fc7d042-621c-4fae-a895-ffab9d2e405f, content: 'Dinosaurs are varied from taxonomic, morphological and ecological standpoints. Birds, at over 11,000...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 1, 'title': 'Dinosaurs'}),
#    Document(id=af4e0b2f-530a-4d34-8d52-b543e93fd852, content: 'While dinosaurs were ancestrally bipedal, many extinct groups included quadrupedal species, and some...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 2, 'title': 'Dinosaurs'}),
#    Document(id=d70e5c97-887a-41ac-9e82-3e21b93e6292, content: 'The first dinosaur fossils were recognized in the early 19th century, with the name "dinosaur" (mean...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 3, 'title': 'Dinosaurs'}),
#    Document(id=fc799092-f063-499a-991a-ad38c2ee8431, content: 'Under phylogenetic nomenclature, dinosaurs are usually defined as the group consisting of the most r...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 4, 'title': 'Dinosaurs', 'h2': 'Definition'}),
#    Document(id=1bb0fe61-c5c9-420b-bb03-8b95aa4c09df, content: 'Birds are the sole surviving dinosaurs. In traditional taxonomy, birds were considered a separate cl...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 5, 'title': 'Dinosaurs', 'h2': 'Definition'}),
#    Document(id=eb2e281a-d9e8-4735-b13d-e777a7c91a56, content: 'Research by Matthew G. Baron, David B. Norman, and Paul M. Barrett in 2017 suggested a radical revis...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 6, 'title': 'Dinosaurs', 'h2': 'Definition'}),
#    Document(id=0a812a18-8b58-4ec8-b00b-a719a1ad1278, content: 'Using one of the above definitions, dinosaurs can be generally described as archosaurs with hind lim...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 7, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'General description'}),
#    Document(id=c673df54-85bf-4a96-969a-2567195498d9, content: 'Dinosaurs were the dominant terrestrial vertebrates of the Mesozoic Era, especially the Jurassic and...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 8, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'General description'}),
#    Document(id=9795236d-b449-44e4-8403-24ac5c5c73d1, content: 'Extinct dinosaurs, as well as modern birds, include genera that are herbivorous and others carnivoro...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 9, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'General description'}),
#    Document(id=17cb34e2-7a79-43a4-9179-98c3b4cde535, content: 'While recent discoveries have made it more difficult to present a universally agreed-upon list of th...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 10, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#    Document(id=9095c0b5-b998-4738-9069-d2ce6fde75b1, content: 'A detailed assessment of archosaur interrelations by Sterling Nesbitt confirmed or found the followi...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 11, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#    Document(id=5a083af4-3b8a-4b6f-9167-f1cbc5b04a26, content: 'In the skull, a supratemporal fossa (excavation) is present in front of the supratemporal fenestra, ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 12, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#    Document(id=16ee761f-f97d-4f46-b4e9-696fcc146d3a, content: 'Epipophyses, obliquely backward-pointing processes on the rear top corners of the anterior (front) n...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 13, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#    Document(id=45f76cc3-76b4-4bf9-81a4-b1f65c4f3a25, content: 'Apex of a deltopectoral crest (a projection on which the deltopectoral muscles attach) located at or...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 14, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#    Document(id=fc892eb0-0ef6-4a7c-99fa-d77a6f9d10ad, content: 'Radius, a lower arm bone, shorter than 80% of humerus length', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 15, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#    Document(id=3719ea51-a20d-4d97-9db0-c1ff76f70763, content: 'Fourth trochanter (projection where the caudofemoralis muscle attaches on the inner rear shaft) on t...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 16, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#    Document(id=f70c7022-11f0-4d58-adb4-0684bdbc8aad, content: 'Fourth trochanter asymmetrical, with distal, lower, margin forming a steeper angle to the shaft', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 17, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#    Document(id=ce261b5d-1564-402a-8e94-7a65558e872b, content: 'On the astragalus and calcaneum, upper ankle bones, the proximal articular facet, the top connecting...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 18, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#    Document(id=c2db46fc-174b-4d23-ad81-b7b5b9b09af5, content: 'Exoccipitals (bones at the back of the skull) do not meet along the midline on the floor of the endo...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 19, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#    Document(id=38e735d2-2fab-4f23-a379-123c7075eb00, content: 'In the pelvis, the proximal articular surfaces of the ischium with the ilium and the pubis are separ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 20, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#    Document(id=5b5a4c57-a9a8-4ee7-bd9e-c008166aa731, content: 'Cnemial crest on the tibia (protruding part of the top surface of the shinbone) arcs anterolaterally...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 21, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#    Document(id=a2c46450-6a73-41d2-90cb-f810b7f11c9a, content: 'Distinct proximodistally oriented (vertical) ridge present on the posterior face of the distal end o...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 22, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#    Document(id=0eb70811-340c-4529-8b3e-fc2fd8b57183, content: 'Concave articular surface for the fibula of the calcaneum (the top surface of the calcaneum, where i...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 23, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#    Document(id=923f4633-5df4-4a23-a2f5-70b3647a3790, content: 'Nesbitt found a number of further potential synapomorphies and discounted a number of synapomorphies...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 24, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#    Document(id=adcc041f-8f56-4356-9c65-f7e3689584a0, content: 'A variety of other skeletal features are shared by dinosaurs. However, because they either are commo...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 25, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#    Document(id=01df4a90-cd83-4dff-a8c0-af940689156c, content: 'Dinosaurs stand with their hind limbs erect in a manner similar to most modern mammals, but distinct...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 26, 'title': 'Dinosaurs', 'h2': 'Definition', 'h3': 'Distinguishing anatomical features'}),
#    Document(id=c9f734ea-fc6e-499d-b98b-343378e267de, content: 'Dinosaur fossils have been known for millennia, although their true nature was not recognized. The C...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 27, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Pre-scientific history'}),
#    Document(id=2c28a5de-68ed-4ab0-a51b-373ec46f5d22, content: 'Scholarly descriptions of what would now be recognized as dinosaur bones first appeared in the late ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 28, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Early dinosaur research'}),
#    Document(id=42b2cbcf-92e5-4c8a-9550-1baccc706da0, content: 'Between 1815 and 1824, the Rev William Buckland, the first Reader of Geology at the University of Ox...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 29, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Early dinosaur research'}),
#    Document(id=417c51c5-c264-41c5-9fdc-4dede7eb1d8e, content: 'The study of these "great fossil lizards" soon became of great interest to European and American sci...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 30, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Early dinosaur research'}),
#    Document(id=208dd935-ba56-461c-a3d5-6f9fecd24720, content: 'In 1858, William Parker Foulke discovered the first known American dinosaur, in marl pits in the sma...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 31, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Discoveries in North America'}),
#    Document(id=582e29eb-285c-4141-b80f-d15a5ad2ad42, content: 'Dinosaur mania was exemplified by the fierce rivalry between Edward Drinker Cope and Othniel Charles...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 32, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Discoveries in North America'}),
#    Document(id=eedcca0b-3dc5-4aac-a879-7e3ca4e971a2, content: 'World War II caused a pause in palaeontological research; after the war, research attention was also...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 33, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': '"Dinosaur renaissance" and beyond'}),
#    Document(id=2d4caf96-cb98-4eb5-a088-c34822d8ca9b, content: 'New revelations were supported by an increase in dinosaur discoveries. Major new dinosaur discoverie...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 34, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': '"Dinosaur renaissance" and beyond'}),
#    Document(id=1aa8922d-6de7-4640-8cbb-85bfcbe105b9, content: 'Prior to the dinosaur renaissance, dinosaurs were mostly classified using the traditional rank-based...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 35, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': '"Dinosaur renaissance" and beyond'}),
#    Document(id=8f118d7e-40b7-4048-887a-1030953a12d2, content: 'Dinosaur fossils are not limited to bones, but also include imprints or mineralized remains of skin ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 36, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Soft tissue and molecular preservation'}),
#    Document(id=15f379c5-7c93-4e16-b8b3-f8112cc85e3f, content: 'Starting from the 1990s, major discoveries of exceptionally preserved fossils in deposits known as c...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 37, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Soft tissue and molecular preservation'}),
#    Document(id=d1ec5998-d1c3-4b99-818b-b77a1c7f7693, content: 'Concurrently, a line of work led by Mary Higby Schweitzer, Jack Horner, and colleagues reported vari...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 38, 'title': 'Dinosaurs', 'h2': 'History of study', 'h3': 'Soft tissue and molecular preservation'}),
#    Document(id=6c176b18-da59-4052-a565-969b5e178f9b, content: 'Dinosaurs diverged from their archosaur ancestors during the Middle to Late Triassic epochs, roughly...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 39, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Origins and early evolution'}),
#    Document(id=b5bbd8cc-0a87-43dc-bf08-2d88148da4f4, content: 'The Ischigualasto Formation (radiometrically dated at 231-230 million years old) has produced the ea...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 40, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Origins and early evolution'}),
#    Document(id=4402d6cb-94a0-4551-a45e-4a3a719919fb, content: 'Less well-preserved remains of the sauropodomorphs Jaklapallisaurus and Nambalia , along with the ea...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 41, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Origins and early evolution'}),
#    Document(id=5290c326-3009-47b7-b21d-5cb372df9ed0, content: 'When dinosaurs appeared, they were not the dominant terrestrial animals. The terrestrial habitats we...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 42, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Origins and early evolution'}),
#    Document(id=9449acee-8599-4f78-86fd-9abb1bb2e9bc, content: 'Dinosaur evolution after the Triassic followed changes in vegetation and the location of continents....', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 43, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Evolution and paleobiogeography'}),
#    Document(id=b0aef034-99bc-4e27-b2dd-e2e5c9703152, content: 'By the Early Cretaceous and the ongoing breakup of Pangaea, dinosaurs were becoming strongly differe...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 44, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Evolution and paleobiogeography'}),
#    Document(id=99888900-a4e0-4b02-b54d-436a66bb8446, content: 'There were three general dinosaur faunas in the Late Cretaceous. In the northern continents of North...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 45, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Evolution and paleobiogeography'}),
#    Document(id=879643f8-a722-4a34-b061-b685ce702fd8, content: 'The Cretaceous–Paleogene extinction event, which occurred approximately 66 million years ago at the ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 46, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Evolution and paleobiogeography'}),
#    Document(id=a32c05e3-917c-4a43-abeb-8e11b8b5a04b, content: 'The surviving lineages of neornithine birds, including the ancestors of modern ratites, ducks and ch...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 47, 'title': 'Dinosaurs', 'h2': 'Evolutionary history', 'h3': 'Evolution and paleobiogeography'}),
#    Document(id=e041d69c-0979-4de4-8263-0809fbe0bda9, content: 'Dinosaurs belong to a group known as archosaurs, which also includes modern crocodilians. Within the...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 48, 'title': 'Dinosaurs', 'h2': 'Classification'}),
#    Document(id=622d9365-79c6-463b-851a-7dd88c9b9469, content: 'Collectively, dinosaurs as a clade are divided into two primary branches, Saurischia and Ornithischi...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 49, 'title': 'Dinosaurs', 'h2': 'Classification'}),
#    Document(id=f4e7976f-5555-4272-8153-970876095213, content: 'By contrast, ornithischians—"bird-hipped", from the Greek ornitheios (ὀρνίθειος) meaning "of a bird"...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 50, 'title': 'Dinosaurs', 'h2': 'Classification'}),
#    Document(id=b2ab981d-4565-4871-8931-cde0dbb9f937, content: 'Despite the terms "bird hip" (Ornithischia) and "lizard hip" (Saurischia), birds are not part of Orn...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 51, 'title': 'Dinosaurs', 'h2': 'Classification'}),
#    Document(id=af1611fa-9809-4f72-93e0-439caf8f27ee, content: 'The following is a simplified classification of dinosaur groups based on their evolutionary relation...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 52, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=235f86c4-4200-4aff-bfb2-a19546873e56, content: 'Dinosauria', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 53, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=b7dc1099-52c9-4921-a621-9034bdda79f9, content: '†Ornithischia ("bird-hipped"; diverse bipedal and quadrupedal herbivores)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 54, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=22e709c9-0d92-4b09-b47a-92d06be09ac4, content: '†Saphornithischia ("true" ornithischians)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 55, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=d280a694-6487-482b-8352-e4ca9ea02c67, content: '†Heterodontosauridae (small herbivores/omnivores with prominent canine-like teeth)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 56, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=0d5bbe06-312c-4844-9ae3-1509e908af25, content: '†Genasauria ("cheeked lizards")', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 57, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=9bc21fa8-0b73-4b11-a597-7248677f8ea3, content: '†Thyreophora (armored dinosaurs; bipeds and quadrupeds)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 58, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=f53f7bdc-c7d0-4741-9abd-e49aaa7a8eba, content: '†Eurypoda (heavy, quadrupedal thyreophorans)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 59, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=499e4fd4-186b-4ea1-82ff-272249148348, content: '†Stegosauria (spikes and plates as primary armor)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 60, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=d5e9805d-6c88-4122-aefd-c37d7d670e4b, content: '†Huayangosauridae (small stegosaurs with flank osteoderms and tail clubs)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 61, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=7ab82755-bf0a-43bc-839d-b288ecf05760, content: '†Stegosauridae (large stegosaurs)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 62, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=b84d656b-bf05-44ba-8937-e5decca5271d, content: '†Ankylosauria (scutes as primary armor)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 63, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=310047ef-305b-40ce-8968-9c15195bc8d2, content: '†Parankylosauria (small, southern ankylosaurs with macuahuitl-like tails)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 64, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=d8ae2828-f325-46c8-a16e-196afd9c30f3, content: '†Nodosauridae (mostly spiky, club-less ankylosaurs)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 65, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=7ad6ec3c-bacd-4d6b-b546-6d0bd46559f5, content: '†Ankylosauridae (characterized by flat scutes)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 66, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=e04bc0ba-23ad-41ac-956c-b592648b3b91, content: '†Ankylosaurinae (club-tailed ankylosaurids)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 67, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=cfeb3074-c48a-4411-aba9-23e003a387d9, content: '†Neornithischia ("new ornithischians")', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 68, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=1bf43502-352e-45e8-86b0-a49ce115f106, content: '†Pyrodontia ("fire teeth")', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 69, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=2b18ab4f-b91e-4591-852c-df4d7bb1efbd, content: '†Thescelosauridae ("wondrous lizards")', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 70, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=26b9de4c-18aa-43ad-bdc3-6fbb69d63298, content: '†Orodrominae (burrowers)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 71, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=45252357-8c54-4622-8217-843ebbbd7678, content: '†Thescelosaurinae (large thescelosaurids)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 72, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=ab28482e-8011-4149-acd1-c5de739260a9, content: '†Cerapoda ("horned feet")', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 73, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=a52e0199-cd1b-4191-87d7-0b4f82ea9b4e, content: '†Marginocephalia (characterized by a cranial growth)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 74, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=e64c72e4-a0a3-4338-9225-caa7f051e9bd, content: '†Pachycephalosauria (bipeds with domed or knobby growth on skulls)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 75, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=12541c1d-a1cd-4487-8db3-e62f8ae2dcad, content: '†Ceratopsia (bipeds and quadrupeds; many had neck frills and horns)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 76, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=623d1e9f-5323-4eaf-8007-c571c4df4ae8, content: '†Chaoyangsauridae (small, frill-less basal ceratopsians)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 77, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=8bcf29dd-0a6c-4466-a153-c95b82d7d192, content: '†Neoceratopsia ("new ceratopsians")', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 78, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=99cb0fa5-d4b1-4922-bbe6-445697894676, content: '†Leptoceratopsidae (little to no frills, hornless, with robust jaws)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 79, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=1f7333a5-b706-4a96-a80a-37299bf7a717, content: '†Protoceratopsidae (basal ceratopsians with small frills and stubby horns)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 80, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=cf7d1813-2534-425d-9b62-17431d34d746, content: '†Ceratopsoidea (large-horned ceratopsians)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 81, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=149cfeb7-28a9-4182-8058-2bd0003272cc, content: '†Ceratopsidae (large, elaborately ornamented ceratopsians)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 82, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=6af55402-dd3d-411e-9c40-30e82da27fb1, content: '†Chasmosaurinae (ceratopsids with enlarged brow horns)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 83, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=a9e39211-773e-4d1b-a53c-0c7531dc1dc2, content: '†Centrosaurinae (ceratopsids mostly characterized by frill and nasal ornamentation)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 84, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=746d8d75-f693-4d85-ad44-3b7732e9f81c, content: '†Nasutoceratopsini (centrosaurines with enlarged nasal cavities)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 85, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=487b4570-4c2c-4745-be50-509764976bf0, content: '†Centrosaurini (centrosaurines with enlarged nasal horns)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 86, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=2ec68390-1b89-49f5-80b6-43d3292c0a32, content: '†Pachyrhinosaurini (mostly had nasal bosses instead of horns)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 87, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=ba7f32a9-caeb-400e-b7a6-d9ab8c24b24e, content: '†Ornithopoda (various sizes; bipeds and quadrupeds; evolved a method of chewing using skull flexibil...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 88, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=3d0e4705-9604-4c18-8e60-cbf7c797a3ad, content: '†Hypsilophodontidae (small European neornithischians)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 89, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=2545de75-7ac3-486d-afe4-4a51f8044bed, content: '†Iguanodontia ("iguana teeth"; advanced ornithopods)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 90, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=04b518cb-d648-4bdc-9bb0-6af09fcb7580, content: '†Rhabdodontomorpha (with distinctive dentition)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 91, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=bd434d53-55da-46ae-a99a-12fb69b8dc19, content: '†Tenontosauridae (North American rhabdodontomorphs; bipeds and quadrupeds)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 92, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=f38ee54c-29de-4d5b-b1de-bb2ff43103f9, content: '†Rhabdodontidae (European rhabdodontomorphs)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 93, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=e8b2f3cc-300a-428f-9f4e-0e55ace4cf16, content: '†Euiguanodontia ("true iguanodonts")', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 94, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=1cda3bcc-8f5f-48ac-bc3c-01c97eea2083, content: '†Elasmaria (mostly southern ornithopods with mineralized plates along the ribs; may be thescelosauri...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 95, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=54aef90e-6eec-464f-8495-cb41d7b8b385, content: '†Dryomorpha ( Dryosaurus and more advanced ornithopods)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 96, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=6b04810f-0c9f-46f9-8a8a-0908fd9ac569, content: '†Dryosauridae (mid-sized, small headed)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 97, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=0cd4d825-3d60-452f-8405-96b34c0d99bf, content: '†Ankylopollexia (early members mid-sized, stocky)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 98, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=fbe5f4fb-45a8-4caa-a8b5-875aa94219d5, content: '†Styracosterna ("spiked sterna")', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 99, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=3d2c364c-b96c-4659-95cc-ef027dc65316, content: '†Hadrosauriformes (ancestrally had a thumb spike; large quadrupedal herbivores, with teeth merged in...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 100, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=cb0ea75d-ef44-4c97-b977-fedb56d8df1e, content: '†Hadrosauromorpha (hadrosaurids and their closest relatives)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 101, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=6ee39688-5dc0-4476-9569-ba725d388d7c, content: '†Hadrosauridae ("duck-billed dinosaurs"; often with crests)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 102, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=abc0a483-56da-49c5-a510-3ab4658c53c7, content: '†Saurolophinae (hadrosaurids with solid, small, no crests)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 103, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=92269400-9ccd-4f63-b1df-aa971c27f816, content: '†Brachylophosaurini (short-crested)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 104, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=c216088a-df33-4bc6-bbc2-45dae50918bf, content: '†Kritosaurini (enlarged, solid nasal crests)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 105, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=b3987417-3865-45fa-8670-f434fc1540fc, content: '†Saurolophini (small, spike-like crests)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 106, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=a88fa858-776a-43ed-b060-d39e287c86ba, content: '†Edmontosaurini (flat-headed saurolophines)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 107, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=3d90c84c-a807-45ef-b09b-5179287eba9d, content: '†Lambeosaurinae (hadrosaurids often with hollow crests)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 108, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=75c676f0-f5f4-4df8-96a9-881dc8485ec3, content: '†Aralosaurini (solid-crested)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 109, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=26272eb5-6ae5-4b46-ad93-a780ac3621e4, content: '†Tsintaosaurini (vertical, tube-like crests)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 110, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=ce6b35c5-ff94-495d-837f-ef4d3af35c01, content: '†Parasaurolophini (long, backwards-arcing crests)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 111, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=03d616c6-d1b4-40c8-82ad-f730ebbbc7a4, content: '†Lambeosaurini (usually rounded crests)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 112, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=aefe91a0-8f8c-4c34-889a-0b83967560a9, content: 'Saurischia', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 113, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=8eb9e8b9-52f9-44ff-bc9d-fb61d2241514, content: '†Herrerasauridae (early bipedal carnivores)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 114, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=f3b88966-6907-40ca-a108-bea35d319f7f, content: '†Sauropodomorpha (herbivores with small heads, long necks, and long tails)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 115, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=ac7607b7-f8b2-4eba-88d0-a196bbe51ff7, content: '†Unaysauridae (primitive, strictly bipedal "prosauropods")', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 116, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=e2ed605a-8de6-4778-a5c5-afa1a32ec762, content: '†Plateosauria (diverse; bipeds and quadrupeds)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 117, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=0c7df351-df11-481d-b019-465685681053, content: '†Massopoda ("heavy feet")', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 118, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=dc366aa2-171e-4431-b292-b38fb71eecea, content: '†Massospondylidae (long-necked, primitive sauropodomorphs)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 119, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=edc317be-c7b1-4e50-99c0-74d469e6104d, content: '†Riojasauridae (large, primitive sauropodomorphs)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 120, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=c25050dc-62c2-4c8c-a040-38a59933a7a2, content: '†Sauropodiformes (heavy, bipeds and quadrupeds)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 121, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=2c7e6aaa-1571-4f12-8090-7fbb5b1d68f1, content: '†Sauropoda (very large and heavy; quadrupedal)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 122, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=a73b7c41-2904-4c0a-aa46-9d19f613acb2, content: '†Lessemsauridae (gigantic yet lacking several weight-saving adaptations)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 123, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=9a291aa7-4375-4195-9403-722821448a44, content: '†Gravisauria ("heavy lizards")', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 124, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=96de91d9-d9bb-40ab-b726-fedabecc3d68, content: '†Eusauropoda ("true sauropods")', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 125, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=041ea16b-a3a2-4f53-8732-c3398328a751, content: '†Turiasauria (often large, widespread sauropods)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 126, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=a5d0563b-f22f-4e7c-95a3-0f2be528ee07, content: '†Neosauropoda ("new sauropods"; columnar limbs)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 127, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=a147867e-ab59-4b0b-96a3-f0dc6c13187a, content: '†Diplodocoidea (skulls and tails elongated; teeth typically narrow and pencil-like)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 128, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=06708eb8-6b60-44d8-bcc5-973ab165362b, content: '†Rebbachisauridae (short-necked, low-browsing diplodocoids often with high backs)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 129, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=b56ff15f-e523-4530-a0fe-f7c6cea36bc5, content: '†Flagellicaudata (whip-tailed)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 130, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=7217b656-ce51-4bd4-81a6-f9f43483b647, content: '†Dicraeosauridae (small, short-necked diplodocoids with enlarged cervical and dorsal vertebrae)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 131, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=ea1d0fa8-fcd9-4012-9c28-ef1cb17f17fa, content: '†Diplodocidae (extremely long-necked)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 132, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=49d624b2-6cf7-4e8f-a335-24f1ab32f03c, content: '†Apatosaurinae (robust cervical vertebrae)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 133, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=7ed5f89d-a87d-40f1-b582-6e4d73dc000c, content: '†Diplodocinae (long, thin necks)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 134, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=66e35c08-0cb9-417c-87fe-4ff66da36dbd, content: '†Macronaria (boxy skulls; spoon- or pencil-shaped teeth)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 135, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=613eaf75-3ad9-4534-9fe6-6b59a5bafd71, content: '†Titanosauriformes ("titan lizard forms")', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 136, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
#    Document(id=fe10943f-9ede-4740-919a-0cd2b75f848f, content: '†Brachiosauridae (long-necked, long-armed macronarians)', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 137, 'title': 'Dinosaurs', 'h2': 'Classification', 'h3': 'Taxonomy'}),
# ...
#    Document(id=15ed0f98-a5b5-4dd4-b9dd-1b3db8dea256, content: 'On the basis that non-avian dinosaurs did not have syrinxes and that their next close living relativ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 213, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Communication'}),
#    Document(id=8a753828-3e20-4a3b-ab7e-259d577fb824, content: 'In 2023, a fossilized larynx was described, from a specimen of the ankylosaurid Pinacosaurus . The s...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 214, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Communication'}),
#    Document(id=3adbe758-7e56-45b4-9a49-bc90f0ce757a, content: 'All dinosaurs laid amniotic eggs. Dinosaur eggs were usually laid in a nest. Most species create som...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 215, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Reproductive biology'}),
#    Document(id=f4a91f09-19d7-4307-b66f-34b0223c2bf8, content: 'When laying eggs, females grow a special type of bone between the hard outer bone and the marrow of ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 216, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Reproductive biology'}),
#    Document(id=0b8cdceb-7ded-47f0-b5b6-9b0fbcab5dd4, content: 'Another widespread trait among modern birds (but see below in regards to fossil groups and extant me...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 217, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Reproductive biology'}),
#    Document(id=d792b3f2-0de5-430f-a88d-183b082e9db8, content: 'However, there is ample evidence of precociality or superprecociality among many dinosaur species, p...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 218, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Reproductive biology'}),
#    Document(id=f7dd5e45-9915-4490-9ce2-5ff7ecac9426, content: 'Genital structures are unlikely to fossilize as they lack scales that may allow preservation via pig...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 219, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Reproductive biology'}),
#    Document(id=a69d1184-e831-469e-92ad-ada64685c738, content: 'Because both modern crocodilians and birds have four-chambered hearts (albeit modified in crocodilia...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 220, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Physiology'}),
#    Document(id=931801b4-c309-4a33-b715-be883cffacea, content: 'After non-avian dinosaurs were discovered, paleontologists first posited that they were ectothermic....', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 221, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Physiology'}),
#    Document(id=ba607532-d09e-492e-bfa0-295628c928ec, content: 'One of the greatest contributions to the modern understanding of dinosaur physiology has been paleoh...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 222, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Physiology'}),
#    Document(id=2e8d7d89-d8b3-460e-a7da-a89e835260af, content: 'In saurischian dinosaurs, higher metabolisms were supported by the evolution of the avian respirator...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 223, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Physiology'}),
#    Document(id=70e1f9c5-1c7f-4552-9dd2-14c4081b54cb, content: 'Like other reptiles, dinosaurs are primarily uricotelic, that is, their kidneys extract nitrogenous ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 224, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Physiology'}),
#    Document(id=4b6a4910-6be9-44cd-9d8a-b32676de52d6, content: 'The size and shape of the brain can be partly reconstructed based on the surrounding bones. In 1896,...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 225, 'title': 'Dinosaurs', 'h2': 'Paleobiology', 'h3': 'Physiology'}),
#    Document(id=769b6b9b-b5e5-4ebf-892c-2c2d73961e3b, content: 'The possibility that dinosaurs were the ancestors of birds was first suggested in 1868 by Thomas Hen...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 226, 'title': 'Dinosaurs', 'h2': 'Origin of birds'}),
#    Document(id=91da2ba4-8b26-4672-99c0-a1fc5ae985aa, content: 'Feathers are one of the most recognizable characteristics of modern birds, and a trait that was also...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 227, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Feathers'}),
#    Document(id=6b8670d7-2233-44fd-bc02-91bc67ededb1, content: 'However, researchers do not agree regarding whether these structures share a common origin between l...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 228, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Feathers'}),
#    Document(id=143146c2-c6c4-4700-b2f7-a9ed038fa107, content: 'Archaeopteryx was the first fossil found that revealed a potential connection between dinosaurs and ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 229, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Feathers'}),
#    Document(id=8b9598ca-49c2-45de-9f30-30d2ea12b6c7, content: 'Because feathers are often associated with birds, feathered dinosaurs are often touted as the missin...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 230, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Skeleton'}),
#    Document(id=8f374deb-2699-486a-9f05-ccd28424164d, content: 'Large meat-eating dinosaurs had a complex system of air sacs similar to those found in modern birds,...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 231, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Soft anatomy'}),
#    Document(id=47c05808-17e6-40e5-a592-bfadfeebfbda, content: 'Fossils of the troodonts Mei and Sinornithoides demonstrate that some dinosaurs slept with their hea...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 232, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Behavioral evidence'}),
#    Document(id=21bafb74-4b82-4658-bdd2-c9d5a2998f4a, content: 'Some dinosaurs are known to have used gizzard stones like modern birds. These stones are swallowed b...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 233, 'title': 'Dinosaurs', 'h2': 'Origin of birds', 'h3': 'Behavioral evidence'}),
#    Document(id=5ec7a711-a2cc-4aae-9aed-c0130e3779d7, content: 'All non-avian dinosaurs and most lineages of birds became extinct in a mass extinction event, called...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 234, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups'}),
#    Document(id=c1973403-a611-4a97-8b54-53391a17bd03, content: 'Just before the K-Pg extinction event, the number of non-avian dinosaur species that existed globall...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 235, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Pre-extinction diversity'}),
#    Document(id=fd2ff0be-020e-47ef-a352-eddc1502d3cb, content: 'The bolide impact hypothesis, first brought to wide attention in 1980 by Walter Alvarez, Luis Alvare...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 236, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Impact event'}),
#    Document(id=98dd5565-e851-4878-89fd-c552f9cc78b4, content: 'Within hours, the Chicxulub impact would have created immediate effects such as earthquakes, tsunami...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 237, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Impact event'}),
#    Document(id=a15b6098-4ca0-4247-b478-620697e7700a, content: 'At the time of the K-Pg extinction, the Deccan Traps flood basalts of India were actively erupting. ...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 238, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Deccan Traps'}),
#    Document(id=59d9e5fc-38df-4c37-840a-fca77532f470, content: 'Before 2000, arguments that the Deccan Traps eruptions—as opposed to the Chicxulub impact—caused the...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 239, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Deccan Traps'}),
#    Document(id=29eaec83-49a4-4f32-b3e9-55ea40ced2ff, content: 'Whether the Deccan Traps were a major cause of the extinction, on par with the Chicxulub impact, rem...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 240, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Deccan Traps'}),
#    Document(id=292fe56d-c0a5-4bff-9d4d-b4add89a1563, content: 'Non-avian dinosaur remains have occasionally been found above the K-Pg boundary. In 2000, Spencer Lu...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 241, 'title': 'Dinosaurs', 'h2': 'Extinction of major groups', 'h3': 'Possible Paleocene survivors'}),
#    Document(id=c913c8b7-4d32-42fd-a277-ff46f716700d, content: 'By human standards, dinosaurs were creatures of fantastic appearance and often enormous size. As suc...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 242, 'title': 'Dinosaurs', 'h2': 'Cultural depictions'}),
#    Document(id=9b67cfa0-d7d6-47a6-88a1-f8279c5c9d23, content: 'Public enthusiasm for dinosaurs first developed in Victorian England, where in 1854, three decades a...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 243, 'title': 'Dinosaurs', 'h2': 'Cultural depictions'}),
#    Document(id=d16afdba-12e8-4057-936b-f3f64bd7a98e, content: 'The popular preoccupation with dinosaurs has ensured their appearance in literature, film, and other...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 244, 'title': 'Dinosaurs', 'h2': 'Cultural depictions'}),
#    Document(id=cb2f5f90-3e40-438d-8aad-8dca11f8507b, content: 'Dinosaur diet and feeding', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 245, 'title': 'Dinosaurs', 'h2': 'See also'}),
#    Document(id=1354b5ae-1764-4384-a461-3d700585f457, content: 'Evolutionary history of life', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 246, 'title': 'Dinosaurs', 'h2': 'See also'}),
#    Document(id=ecc6ae87-0630-46db-afdf-ebc4fe7f45ee, content: 'Lists of dinosaur-bearing stratigraphic units', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 247, 'title': 'Dinosaurs', 'h2': 'See also'}),
#    Document(id=614cff82-f3e1-47f2-ad86-248c4844b26e, content: 'List of dinosaur genera', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 248, 'title': 'Dinosaurs', 'h2': 'See also'}),
#    Document(id=e160fe4b-4a7e-4274-b3b5-0942eed9be8e, content: 'List of bird genera', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 249, 'title': 'Dinosaurs', 'h2': 'See also'}),
#    Document(id=166b8704-b123-4c8c-bfe2-66b0836bd366, content: 'List of birds', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 250, 'title': 'Dinosaurs', 'h2': 'See also'}),
#    Document(id=f3468e28-241c-4be1-ac61-9994e33e4420, content: 'List of informally named dinosaurs', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 251, 'title': 'Dinosaurs', 'h2': 'See also'}),
#    Document(id=20c89a27-839e-4acc-9293-c010c20cc2b7, content: 'List of films featuring dinosaurs', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 252, 'title': 'Dinosaurs', 'h2': 'See also'}),
#    Document(id=8e5eb2bd-d910-4fdc-90bb-86eddc389ff5, content: 'University of Southampton (September 29, 2021). "Two New Species of Large Predatory Dinosaur With Cr...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 253, 'title': 'Dinosaurs', 'h2': 'Further reading'}),
#    Document(id=3efc089d-cd81-40a1-8e04-9e6c9ed1095d, content: 'Zhou, Zhonghe (October 2004). "The origin and early evolution of birds: discoveries, disputes, and p...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 254, 'title': 'Dinosaurs', 'h2': 'Further reading'}),
#    Document(id=526fe4d9-2a61-4522-b5f0-8af478203ad3, content: 'Paul, Gregory S. (2002). Dinosaurs of the Air: The Evolution and Loss of Flight in Dinosaurs and Bir...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 255, 'title': 'Dinosaurs', 'h2': 'Further reading'}),
#    Document(id=69542b05-c8eb-43d2-82c0-7953cbe05dbb, content: 'Stewart, Tabori & Chang (1997). The Humongous Book of Dinosaurs . New York: Stewart, Tabori & Chang....', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 256, 'title': 'Dinosaurs', 'h2': 'Further reading'}),
#    Document(id=6c3841dd-bbcd-4912-bb0f-60de36d55c8f, content: 'Sternberg, Charles Mortram (1966) [Original edition published by E. Cloutier, printer to the King, 1...', meta: {'file_path': 'Dinosaur.html', 'source_id': '93000a3fb02b99d2d115cd4042256d2f5db2a0ff3928927ca14465276534a75e', 'split_id': 257, 'title': 'Dinosaurs', 'h2': 'Further reading'})]}}

# %% [markdown]
# Sanity checks
