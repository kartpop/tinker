# %% [markdown]
# ### Matplotlib plots

# %%
import matplotlib.pyplot as plt

# Define colors
block_color = 'darkblue'
arrow_color = 'darkorange'
label_color = 'darkgrey'

# Create a simple free body diagram
fig, ax = plt.subplots()

# Draw the object as a rectangle centered at (0, 0)
rectangle = plt.Rectangle((-0.25, -0.1), 0.5, 0.2, fill=False, edgecolor=block_color, linewidth=2)
ax.add_patch(rectangle)

# Draw forces starting from the edges of the rectangular block
ax.arrow(0, 0.1, 0, 0.5, head_width=0.05, head_length=0.1, fc=arrow_color, ec=arrow_color)
ax.arrow(0, -0.1, 0, -0.5, head_width=0.05, head_length=0.1, fc=arrow_color, ec=arrow_color)
ax.arrow(0.25, 0, 0.5, 0, head_width=0.05, head_length=0.1, fc=arrow_color, ec=arrow_color)
ax.arrow(-0.25, 0, -0.5, 0, head_width=0.05, head_length=0.1, fc=arrow_color, ec=arrow_color)

# Add labels slightly eccentric to the axes
ax.text(0.05, 0.65, 'F1', ha='center', color=label_color)
ax.text(0.05, -0.65, 'F2', ha='center', color=label_color)
ax.text(0.75, 0.05, 'F3', va='center', color=label_color)
ax.text(-0.75, 0.05, 'F4', va='center', color=label_color)

# Set limits and hide axes
ax.set_xlim(-1, 1)  # Adjusted x-axis limits for better visibility
ax.set_ylim(-1, 1)
ax.axis('off')

plt.show()

# %% [markdown]
# ### SymPy with Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp

# Define the symbolic variable and function
x = sp.symbols('x')
f = sp.sin(x) * sp.exp(-x / 2)

# Compute the derivative symbolically
f_prime = sp.diff(f, x)

# Convert the symbolic expressions to numerical functions
f_num = sp.lambdify(x, f, 'numpy')
f_prime_num = sp.lambdify(x, f_prime, 'numpy')

# Generate x values
x_vals = np.linspace(0, 10, 400)

# Compute y values for the function and its derivative
y_vals = f_num(x_vals)
y_prime_vals = f_prime_num(x_vals)

# Plot the function and its derivative
plt.figure(figsize=(10, 6))
plt.plot(x_vals, y_vals, label='$f(x) = \sin(x) e^{-x/2}$', color='blue')
plt.plot(x_vals, y_prime_vals, label="$f'(x)$", color='red', linestyle='--')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title('Function and its Derivative')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_12709/307291233.py:25: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(x_vals, y_vals, label='$f(x) = \sin(x) e^{-x/2}$', color='blue')

# %% [markdown]
# ### Draw free-body diagrams using prompt

# %% [markdown]
# Sample system prompt:
#
# """
# You are an AI assistant that generates Python scripts using Matplotlib to create diagrams illustrating the concepts described in the provided context text.
#
# Your task is as follows:
#
# - **Analyze** the context text and identify key concepts that can be visually represented.
# - **Plan** step-by-step what to include in the diagram, and write this plan in pseudocode with great detail.
# - **Output** the complete Python code in a single code block, including necessary imports.
# - **Minimize** any other prose.
# - **Format** your answer using Markdown, and include the programming language name at the start of the code block (e.g., `python`).
#
# Do not include any additional explanations or text. Your code should be complete and runnable as-is to generate the diagram.
# """

# %%
prompt = """

You are an AI assistant that generates Python scripts using Matplotlib to create diagrams illustrating the concepts described in the provided context text.

Your task is as follows:

- **Analyze** the context text and identify key concepts that can be visually represented.
- **Plan** step-by-step what to include in the diagram, and write this plan in pseudocode with great detail.
- **Output** the complete Python code in a single code block, including necessary imports.
- **Minimize** any other prose.
- **Format** your answer using Markdown, and include the programming language name at the start of the code block (e.g., `python`).

Do not include any additional explanations or text. Your code should be complete and runnable as-is to generate the diagram.


**CONTEXT**:

Newton's second law of motion states that the acceleration of an object is directly proportional to the net force acting on it and inversely proportional to its mass. This can be mathematically represented by the formula:

\[ F = ma \]

Where:
- \( F \) is the net force acting on the object (measured in newtons),
- \( m \) is the mass of the object (measured in kilograms),
- \( a \) is the acceleration of the object (measured in meters per second squared).

In simpler terms, this law implies that the greater the force applied to an object, the greater its acceleration will be, and the more massive the object, the less acceleration it will have for the same amount of force applied.
"""
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\['
# <>:1: SyntaxWarning: invalid escape sequence '\['
# /tmp/ipykernel_12709/1020341820.py:1: SyntaxWarning: invalid escape sequence '\['
#   prompt = """

# %%
from openai import OpenAI

client = OpenAI()

# %%
 messages = [{"role": "system", "content": prompt}]

response = client.chat.completions.create(
    model="gpt-4o-mini",  # Replace with the correct engine name
    n=1,
    stop=None,
    temperature=0.7,
    messages=messages,
)

# Print the response
print(response.choices[0].text.strip())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 12
#       3 response = client.chat.completions.create(
#       4    model="gpt-4o-mini",  # Replace with the correct engine name
#       5    n=1,
#    (...)
#       8    messages=messages,
#       9 )
#      11 # Print the response
# ---> 12 print(response.choices[0].text.strip())
#
# File ~/miniconda3/envs/argonk/lib/python3.12/site-packages/pydantic/main.py:828, in BaseModel.__getattr__(self, item)
#     825     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#     826 else:
#     827     # this is the current error
# --> 828     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'Choice' object has no attribute 'text'

# %%
print(response.choices[0].message.content)
# Out:
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Step 1: Define the parameters for the forces, masses, and accelerations
# masses = np.array([1, 2, 3, 4, 5])  # Masses in kg
# forces = np.array([10, 20, 30, 40, 50])  # Forces in N
#
# # Step 2: Calculate the accelerations using F = ma
# accelerations = forces / masses[:, np.newaxis]  # Calculate acceleration for each mass with each force
#
# # Step 3: Create a plot
# plt.figure(figsize=(10, 6))
#
# # Step 4: Plot the accelerations
# for i, mass in enumerate(masses):
#     plt.plot(forces, accelerations[i], label=f'Mass = {mass} kg')
#
# # Step 5: Add labels and title
# plt.title("Acceleration vs. Force for Different Masses")
# plt.xlabel("Force (N)")
# plt.ylabel("Acceleration (m/s²)")
# plt.grid(True)
# plt.legend()
#
# # Step 6: Show the plot
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

# Step 1: Define the parameters for the forces, masses, and accelerations
masses = np.array([1, 2, 3, 4, 5])  # Masses in kg
forces = np.array([10, 20, 30, 40, 50])  # Forces in N

# Step 2: Calculate the accelerations using F = ma
accelerations = forces / masses[:, np.newaxis]  # Calculate acceleration for each mass with each force

# Step 3: Create a plot
plt.figure(figsize=(10, 6))

# Step 4: Plot the accelerations
for i, mass in enumerate(masses):
    plt.plot(forces, accelerations[i], label=f'Mass = {mass} kg')

# Step 5: Add labels and title
plt.title("Acceleration vs. Force for Different Masses")
plt.xlabel("Force (N)")
plt.ylabel("Acceleration (m/s²)")
plt.grid(True)
plt.legend()

# Step 6: Show the plot
plt.show()

# %% [markdown]
# ### Another experiment with a different prompt

# %%
context = """**Lift**: This is the force that allows planes to rise off the ground. It's generated by the wings of the plane. Imagine a bird flapping its wings. As air flows over and under the wings, it creates a difference in air pressure. The shape of the wing (called an airfoil) is designed so that air moves faster over the top of the wing than underneath it. According to Bernoulli's principle, the faster air on top creates a lower pressure compared to the higher pressure underneath. This pressure difference creates lift, allowing the plane to ascend."""

# %%
prompt = f"""

You are an AI assistant that generates Python scripts using Matplotlib to create diagrams illustrating the concepts described in the provided context text.

Your task is as follows:

- **Analyze** the context text and identify key concepts that can be visually represented.
- **Plan** step-by-step what to include in the diagram, and write this plan in pseudocode with great detail.
- **Output** the complete Python code in a single code block, including necessary imports.
- **Minimize** any other prose.
- **Format** your answer using Markdown, and include the programming language name at the start of the code block (e.g., `python`).

Do not include any additional explanations or text. Your code should be complete and runnable as-is to generate the diagram.


**CONTEXT**:

{context}"""

# %%
messages = [{"role": "system", "content": prompt}]

response = client.chat.completions.create(
    model="gpt-4o-mini",  # Replace with the correct engine name
    n=1,
    stop=None,
    temperature=0.7,
    messages=messages,
)

print(response.choices[0].message.content)
# Out:
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Set up the figure and axis
# fig, ax = plt.subplots(figsize=(10, 5))
#
# # Define the airfoil shape using a simple curve
# x = np.linspace(-1, 1, 100)
# y_upper = 0.2 * np.sqrt(1 - (x**2))  # Upper surface of the airfoil
# y_lower = -0.1 * np.sqrt(1 - (x**2))  # Lower surface of the airfoil
#
# # Plot the airfoil
# ax.plot(x, y_upper, color='blue', label='Upper Wing Surface (Lower Pressure)')
# ax.plot(x, y_lower, color='red', label='Lower Wing Surface (Higher Pressure)')
# ax.fill_between(x, y_upper, y_lower, color='gray', alpha=0.5)
#
# # Add arrows to indicate air flow
# ax.annotate('', xy=(-1.5, 0), xytext=(-2, 0),
#             arrowprops=dict(facecolor='black', shrink=0.05))
# ax.annotate('', xy=(1.5, 0), xytext=(2, 0),
#             arrowprops=dict(facecolor='black', shrink=0.05))
#
# # Add labels for pressure areas
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 5))

# Define the airfoil shape using a simple curve
x = np.linspace(-1, 1, 100)
y_upper = 0.2 * np.sqrt(1 - (x**2))  # Upper surface of the airfoil
y_lower = -0.1 * np.sqrt(1 - (x**2))  # Lower surface of the airfoil

# Plot the airfoil
ax.plot(x, y_upper, color='blue', label='Upper Wing Surface (Lower Pressure)')
ax.plot(x, y_lower, color='red', label='Lower Wing Surface (Higher Pressure)')
ax.fill_between(x, y_upper, y_lower, color='gray', alpha=0.5)

# Add arrows to indicate air flow
ax.annotate('', xy=(-1.5, 0), xytext=(-2, 0),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('', xy=(1.5, 0), xytext=(2, 0),
            arrowprops=dict(facecolor='black', shrink=0.05))

# Add labels for pressure areas
ax.text(0, 0.15, 'Lower Pressure', horizontalalignment='center', fontsize=12, color='blue')
ax.text(0, -0.25, 'Higher Pressure', horizontalalignment='center', fontsize=12, color='red')

# Set limits and labels
ax.set_xlim(-2, 2)
ax.set_ylim(-0.5, 0.5)
ax.set_title('Lift Generation on an Airfoil')
ax.set_xlabel('Horizontal Distance')
ax.set_ylabel('Vertical Distance')
ax.axhline(0, color='black', lw=0.5)
ax.axvline(0, color='black', lw=0.5)

# Add legend
ax.legend()

# Show the plot
plt.grid()
plt.show()

# %% [markdown]
# ### Critique agent - try to check if LLM can critique teh matplotlib plot created by previous agent

# %%
context = """**Lift**: This is the force that allows planes to rise off the ground. It's generated 
by the wings of the plane. Imagine a bird flapping its wings. As air flows over and under the wings, 
it creates a difference in air pressure. The shape of the wing (called an airfoil) is designed so 
that air moves faster over the top of the wing than underneath it. According to Bernoulli's principle, 
the faster air on top creates a lower pressure compared to the higher pressure underneath. This 
pressure difference creates lift, allowing the plane to ascend."""

# %%
code = """
```python
import matplotlib.pyplot as plt
import numpy as np

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 5))

# Define the airfoil shape using a simple curve
x = np.linspace(-1, 1, 100)
y_upper = 0.2 * np.sqrt(1 - (x**2))  # Upper surface of the airfoil
y_lower = -0.1 * np.sqrt(1 - (x**2))  # Lower surface of the airfoil

# Plot the airfoil
ax.plot(x, y_upper, color='blue', label='Upper Wing Surface (Lower Pressure)')
ax.plot(x, y_lower, color='red', label='Lower Wing Surface (Higher Pressure)')
ax.fill_between(x, y_upper, y_lower, color='gray', alpha=0.5)

# Add arrows to indicate air flow
ax.annotate('', xy=(-1.5, 0), xytext=(-2, 0),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('', xy=(1.5, 0), xytext=(2, 0),
            arrowprops=dict(facecolor='black', shrink=0.05))

# Add labels for pressure areas
ax.text(0, 0.15, 'Lower Pressure', horizontalalignment='center', fontsize=12, color='blue')
ax.text(0, -0.25, 'Higher Pressure', horizontalalignment='center', fontsize=12, color='red')

# Set limits and labels
ax.set_xlim(-2, 2)
ax.set_ylim(-0.5, 0.5)
ax.set_title('Lift Generation on an Airfoil')
ax.set_xlabel('Horizontal Distance')
ax.set_ylabel('Vertical Distance')
ax.axhline(0, color='black', lw=0.5)
ax.axvline(0, color='black', lw=0.5)

# Add legend
ax.legend()

# Show the plot
plt.grid()
plt.show()
```
"""

# %%
prompt = f"""

You are an AI assistant that critiques Python scripts created using Matplotlib to create diagrams illustrating the concepts described in the provided context text.

Your task is as follows:

- **Analyze** the context text and identify key concepts that can be visually represented.
- **Critcally analyze** the code provided and identify any issues, errors, or improvements that can be made.
- **Provide** constructive feedback on the code, highlighting areas of improvement.
- **Output** the complete and corrected (if required) Python code in a single code block, including necessary imports.
- **Minimize** any other prose.
- **Format** your answer using Markdown, and include the programming language name at the start of the code block (e.g., `python`).


Only include the constructive feedback and corrected code. Your code should be complete and runnable as-is to generate the diagram.


**CONTEXT**:

{context}


**CODE**:

{code}

"""

# %%
messages = [{"role": "system", "content": prompt}]

response = client.chat.completions.create(
    model="gpt-4o-mini",  # Replace with the correct engine name
    n=1,
    stop=None,
    temperature=0.7,
    messages=messages,
)

print(response.choices[0].message.content)
# Out:
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Set up the figure and axis
# fig, ax = plt.subplots(figsize=(10, 5))
#
# # Define the airfoil shape using a simple curve
# x = np.linspace(-1, 1, 100)
# y_upper = 0.2 * np.sqrt(1 - (x**2))  # Upper surface of the airfoil
# y_lower = -0.1 * np.sqrt(1 - (x**2))  # Lower surface of the airfoil
#
# # Plot the airfoil
# ax.plot(x, y_upper, color='blue', label='Upper Wing Surface (Lower Pressure)')
# ax.plot(x, y_lower, color='red', label='Lower Wing Surface (Higher Pressure)')
# ax.fill_between(x, y_upper, y_lower, color='gray', alpha=0.5)
#
# # Add arrows to indicate air flow
# ax.annotate('', xy=(-1.5, 0), xytext=(-2, 0),
#             arrowprops=dict(facecolor='black', shrink=0.05))
# ax.annotate('', xy=(1.5, 0), xytext=(2, 0),
#             arrowprops=dict(facecolor='black', shrink=0.05))
#
# # Add labels for pressure areas
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 5))

# Define the airfoil shape using a simple curve
x = np.linspace(-1, 1, 100)
y_upper = 0.2 * np.sqrt(1 - (x**2))  # Upper surface of the airfoil
y_lower = -0.1 * np.sqrt(1 - (x**2))  # Lower surface of the airfoil

# Plot the airfoil
ax.plot(x, y_upper, color='blue', label='Upper Wing Surface (Lower Pressure)')
ax.plot(x, y_lower, color='red', label='Lower Wing Surface (Higher Pressure)')
ax.fill_between(x, y_upper, y_lower, color='gray', alpha=0.5)

# Add arrows to indicate air flow
ax.annotate('', xy=(-1.5, 0), xytext=(-2, 0),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('', xy=(1.5, 0), xytext=(2, 0),
            arrowprops=dict(facecolor='black', shrink=0.05))

# Add labels for pressure areas
ax.text(0, 0.25, 'Lower Pressure', horizontalalignment='center', fontsize=12, color='blue')
ax.text(0, -0.35, 'Higher Pressure', horizontalalignment='center', fontsize=12, color='red')

# Set limits and labels
ax.set_xlim(-2, 2)
ax.set_ylim(-0.5, 0.5)
ax.set_title('Lift Generation on an Airfoil')
ax.set_xlabel('Horizontal Distance')
ax.set_ylabel('Vertical Distance')
ax.axhline(0, color='black', lw=0.5)
ax.axvline(0, color='black', lw=0.5)

# Add grid and legend
ax.grid()
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# Outputted exactly the same diagram. Critique does not help. What if we ask it only to critique it and do nothing else?

# %%
prompt = f"""

You are an AI assistant that critiques Python scripts created using Matplotlib to create diagrams illustrating the concepts described in the provided context text.

Your task is as follows:

- **Analyze** the context text and identify key concepts that can be visually represented.
- **Critcally analyze** the code provided and identify any issues, errors, or improvements that can be made.
- **Provide** constructive feedback on the code, highlighting areas of improvement.


Only include the constructive feedback in your answer.


**CONTEXT**:

{context}


**CODE**:

{code}

"""

# %%
messages = [{"role": "system", "content": prompt}]

response = client.chat.completions.create(
    model="gpt-4o-mini",  # Replace with the correct engine name
    n=1,
    stop=None,
    temperature=0.7,
    messages=messages,
)

print(response.choices[0].message.content)
# Out:
# 1. **Airfoil Representation**: The current representation of the airfoil shape is somewhat simplistic. Real airfoils have more complex shapes. Consider using a predefined airfoil shape from a library or generating a more realistic airfoil curve to better illustrate the concept.
#
# 2. **Pressure Labels**: The labels "Lower Pressure" and "Higher Pressure" are not positioned accurately relative to the airfoil. It would be more effective to place them closer to the respective surfaces of the airfoil to visually indicate which surface corresponds to which pressure.
#
# 3. **Arrow Representation**: The arrows indicating air flow could be enhanced by using multiple arrows or a curved path to show the direction of the airflow more clearly. This would help in visualizing how air moves over the airfoil.
#
# ...

# %% [markdown]
# The above does not point out that the arrows in both direction are incorrect.

# %%
prompt = f"""

You are an AI assistant that critiques Python scripts created using Matplotlib to create diagrams illustrating the concepts described in the provided context text.

Your task is as follows:

**MOST IMPORTANT**: Does the code accurately represent the concept suggested in the context? Are there any fundamental flaws in the depiction of the concept?

Also analyze the labels and annotations. Do they provide clear information about the diagram? Are they placed correctly?

Only include the constructive feedback in your answer.


**CONTEXT**:

{context}


**CODE**:

{code}

"""

# %%
messages = [{"role": "system", "content": prompt}]

response = client.chat.completions.create(
    model="gpt-4o-mini",  # Replace with the correct engine name
    n=1,
    stop=None,
    temperature=0.7,
    messages=messages,
)

print(response.choices[0].message.content)
# Out:
# The code accurately represents the concept of lift generation on an airfoil, effectively illustrating the difference in pressure above and below the wing. However, there are a few areas for improvement regarding clarity and accuracy:
#
# 1. **Airfoil Shape Representation**: The shape of the airfoil is simplified in the code. While it serves the purpose, a more realistic airfoil shape would enhance understanding. Consider using a well-defined airfoil profile rather than a simplistic curve.
#
# 2. **Pressure Labels**: The labels for 'Lower Pressure' and 'Higher Pressure' are correctly positioned relative to the airfoil surfaces. However, the colors used may cause confusion. It would be clearer to label the upper surface as 'Lower Pressure' in blue and the lower surface as 'Higher Pressure' in red, but ensure the placement does not imply a vertical relationship since they are not positioned directly above/below the surfaces.
#
# ...

# %% [markdown]
# Still does not exactly figure out the issue, but let's proceed.

# %% [markdown]
# Original critique:

# %%
critique = """

1. **Airfoil Representation**: The current representation of the airfoil shape is somewhat simplistic. Real airfoils have more complex shapes. Consider using a predefined airfoil shape from a library or generating a more realistic airfoil curve to better illustrate the concept.

2. **Pressure Labels**: The labels "Lower Pressure" and "Higher Pressure" are not positioned accurately relative to the airfoil. It would be more effective to place them closer to the respective surfaces of the airfoil to visually indicate which surface corresponds to which pressure.

3. **Arrow Representation**: The arrows indicating air flow could be enhanced by using multiple arrows or a curved path to show the direction of the airflow more clearly. This would help in visualizing how air moves over the airfoil.

4. **Aspect Ratio**: The aspect ratio of the plot may not effectively convey the concept of lift. Consider adjusting the y-limits or using a more elongated shape to emphasize the differences in pressure above and below the wing.

5. **Color Scheme**: The current colors (blue for lower pressure and red for higher pressure) might be misleading because red typically indicates danger or high temperatures. Consider using colors that are more intuitively linked to pressure, such as blue for higher pressure and green for lower pressure.

6. **Grid Visibility**: The grid is added, but it may be too subtle in this context. Increasing the grid line thickness or changing the grid color could improve visibility and help the viewer better gauge distances and pressures.

7. **Annotations**: The annotations for the airflow direction could be more descriptive. Instead of just arrows, consider adding text labels to clarify the airflow direction (e.g., "Airflow Direction").

8. **Code Comments**: While there are comments in the code, they could be expanded to provide more context about each step, such as explaining why the airfoil shape is chosen or what Bernoulli's principle entails.

9. **Figure Display**: To enhance usability, consider adding a `plt.savefig()` command to allow users to save the figure for further analysis or presentations.

10. **Title and Axis Labels**: The title and axis labels are functional but could be more descriptive. For example, the title could explicitly mention "Pressure Differences on an Airfoil" to tie back to the concept of lift and pressure differences more clearly.


"""

# %%
prompt = f"""

You are an AI assistant that generates Python scripts using Matplotlib to create diagrams illustrating the concepts described in the provided context text.

Both the previously generated code and its critical analysis is included below. Your task is to address the issues mentioned in the critique and provide an improved version of the code.

Remember the following:

- **Output** the complete Python code in a single code block, including necessary imports.
- **Minimize** any other prose.
- **Format** your answer using Markdown, and include the programming language name at the start of the code block (e.g., `python`).

Do not include any additional explanations or text. Your code should be complete and runnable as-is to generate the diagram.


**CONTEXT**:

{context}

**CODE**:

{code}

**CRITIQUE**:
    
{critique}

    """

# %%
messages = [{"role": "system", "content": prompt}]

response = client.chat.completions.create(
    model="gpt-4o-mini",  # Replace with the correct engine name
    n=1,
    stop=None,
    temperature=0.7,
    messages=messages,
)

print(response.choices[0].message.content)
# Out:
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Set up the figure and axis
# fig, ax = plt.subplots(figsize=(12, 6))
#
# # Define a more realistic airfoil shape (NACA 2412)
# x = np.linspace(-1, 1, 100)
# y_upper = 0.12 * (0.2969 * np.sqrt(x + 1e-6) - 0.1260 * (x + 1e-6) - 0.3516 * (x + 1e-6)**2 +
#                   0.2843 * (x + 1e-6)**3 - 0.1015 * (x + 1e-6)**4)  # Upper surface
# y_lower = -0.1 * np.sqrt(1 - (x**2))  # Lower surface (simplified)
#
# # Plot the airfoil
# ax.plot(x, y_upper, color='green', label='Upper Wing Surface (Lower Pressure)')
# ax.plot(x, y_lower, color='blue', label='Lower Wing Surface (Higher Pressure)')
# ax.fill_between(x, y_upper, y_lower, color='lightgray', alpha=0.5)
#
# # Add arrows to indicate air flow with labels
# for i in range(-1, 2, 1):
#     ax.annotate('', xy=(i, 0.2), xytext=(i, 0.5),
#                 arrowprops=dict(facecolor='black', shrink=0.05))
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 6))

# Define a more realistic airfoil shape (NACA 2412)
x = np.linspace(-1, 1, 100)
y_upper = 0.12 * (0.2969 * np.sqrt(x + 1e-6) - 0.1260 * (x + 1e-6) - 0.3516 * (x + 1e-6)**2 + 
                  0.2843 * (x + 1e-6)**3 - 0.1015 * (x + 1e-6)**4)  # Upper surface
y_lower = -0.1 * np.sqrt(1 - (x**2))  # Lower surface (simplified)

# Plot the airfoil
ax.plot(x, y_upper, color='green', label='Upper Wing Surface (Lower Pressure)')
ax.plot(x, y_lower, color='blue', label='Lower Wing Surface (Higher Pressure)')
ax.fill_between(x, y_upper, y_lower, color='lightgray', alpha=0.5)

# Add arrows to indicate air flow with labels
for i in range(-1, 2, 1):
    ax.annotate('', xy=(i, 0.2), xytext=(i, 0.5),
                arrowprops=dict(facecolor='black', shrink=0.05))
    ax.text(i, 0.55, 'Airflow Direction', horizontalalignment='center', fontsize=10, color='black')

# Add labels for pressure areas
ax.text(0.5, 0.15, 'Lower Pressure', horizontalalignment='center', fontsize=12, color='green')
ax.text(0.5, -0.25, 'Higher Pressure', horizontalalignment='center', fontsize=12, color='blue')

# Set limits and labels
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-0.5, 0.6)
ax.set_title('Pressure Differences on an Airfoil', fontsize=14)
ax.set_xlabel('Horizontal Distance', fontsize=12)
ax.set_ylabel('Vertical Distance', fontsize=12)
ax.axhline(0, color='black', lw=0.5)
ax.axvline(0, color='black', lw=0.5)

# Add grid with increased visibility
ax.grid(color='gray', linestyle='--', linewidth=0.7)

# Add legend
ax.legend()

# Save the figure as a file
plt.savefig('airfoil_lift_diagram.png', dpi=300)

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_6716/2592925963.py:9: RuntimeWarning: invalid value encountered in sqrt
#   y_upper = 0.12 * (0.2969 * np.sqrt(x + 1e-6) - 0.1260 * (x + 1e-6) - 0.3516 * (x + 1e-6)**2 +

# %% [markdown]
# The original critique has produced ridiculous results. This is completely wrong. The original plot creation (with just the context given and nothing else is better)

# %% [markdown]
# Try with the second critique.

# %%
critique = """

The code accurately represents the concept of lift generation on an airfoil, effectively illustrating the difference in pressure above and below the wing. However, there are a few areas for improvement regarding clarity and accuracy:

1. **Airfoil Shape Representation**: The shape of the airfoil is simplified in the code. While it serves the purpose, a more realistic airfoil shape would enhance understanding. Consider using a well-defined airfoil profile rather than a simplistic curve.

2. **Pressure Labels**: The labels for 'Lower Pressure' and 'Higher Pressure' are correctly positioned relative to the airfoil surfaces. However, the colors used may cause confusion. It would be clearer to label the upper surface as 'Lower Pressure' in blue and the lower surface as 'Higher Pressure' in red, but ensure the placement does not imply a vertical relationship since they are not positioned directly above/below the surfaces.

3. **Arrow Direction**: The arrows indicating airflow are not clearly labeled. Adding labels such as "Airflow Direction" next to the arrows would provide context for what they represent and enhance understanding of the airflow dynamics.

4. **Annotation of Bernoulli’s Principle**: Including a brief annotation or note that explains Bernoulli's principle, or how the pressure difference leads to lift, would add educational value to the diagram.

5. **X and Y Axis Labels**: The x-axis is labeled "Horizontal Distance" and the y-axis "Vertical Distance", but these labels do not directly relate to the concept of lift. It might be more helpful to label the x-axis as "Position Along Airfoil" and the y-axis as "Height Above/Below Airfoil" to provide a clearer context.

6. **Legend Clarity**: The legend states "Lower Wing Surface" and "Higher Wing Surface." The terms "upper" and "lower" would be more accurate in the context of the airfoil, as they correspond to the actual surfaces of the wing.

7. **Grid Lines**: While the grid can help in visualizing the plot, consider whether it might distract from the main focus of the airfoil and the pressure difference. Adjusting the grid’s visibility or style could help emphasize the main elements.

Overall, the code effectively conveys the fundamental concept of lift, but refining these details could significantly enhance the clarity and educational value of the diagram.


"""

# %%
code = """

```python
import matplotlib.pyplot as plt
import numpy as np

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 5))

# Define the airfoil shape using a simple curve
x = np.linspace(-1, 1, 100)
y_upper = 0.2 * np.sqrt(1 - (x**2))  # Upper surface of the airfoil
y_lower = -0.1 * np.sqrt(1 - (x**2))  # Lower surface of the airfoil

# Plot the airfoil
ax.plot(x, y_upper, color='blue', label='Upper Wing Surface (Lower Pressure)')
ax.plot(x, y_lower, color='red', label='Lower Wing Surface (Higher Pressure)')
ax.fill_between(x, y_upper, y_lower, color='gray', alpha=0.5)

# Add arrows to indicate air flow
ax.annotate('', xy=(-1.5, 0), xytext=(-2, 0),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('', xy=(1.5, 0), xytext=(2, 0),
            arrowprops=dict(facecolor='black', shrink=0.05))

# Add labels for pressure areas
ax.text(0, 0.15, 'Lower Pressure', horizontalalignment='center', fontsize=12, color='blue')
ax.text(0, -0.25, 'Higher Pressure', horizontalalignment='center', fontsize=12, color='red')

# Set limits and labels
ax.set_xlim(-2, 2)
ax.set_ylim(-0.5, 0.5)
ax.set_title('Lift Generation on an Airfoil')
ax.set_xlabel('Horizontal Distance')
ax.set_ylabel('Vertical Distance')
ax.axhline(0, color='black', lw=0.5)
ax.axvline(0, color='black', lw=0.5)

# Add legend
ax.legend()

# Show the plot
plt.grid()
plt.show()
```

"""

# %%
prompt = f"""

You are an AI assistant that generates Python scripts using Matplotlib to create diagrams illustrating the concepts described in the provided context text.

Both the previously generated code and its critical analysis is included below. Your task is to address the issues mentioned in the critique and provide an improved version of the code.

Remember the following:

- **Analyze** the context text and crique text and identify changes to be made.
- **Plan** step-by-step what to include in the diagram, and write this plan in pseudocode with great detail.
- **Output** the complete Python code in a single code block, including necessary imports.
- **Ensure** the code accurately represents the concept suggested in the context. Make sure no bugs have crept in during the changes. If mistakes exist, go back to previous step.
- **Minimize** any other prose.
- **Format** your answer using Markdown, and include the programming language name at the start of the code block (e.g., `python`).

Do not include any additional explanations or text. Your code should be complete and runnable as-is to generate the diagram.


**CONTEXT**:

{context}

**CODE**:

{code}

**CRITIQUE**:
    
{critique}

    """

# %%
messages = [{"role": "system", "content": prompt}]

response = client.chat.completions.create(
    model="gpt-4o-mini",  # Replace with the correct engine name
    n=1,
    stop=None,
    temperature=0.7,
    messages=messages,
)

print(response.choices[0].message.content)
# Out:
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Set up the figure and axis
# fig, ax = plt.subplots(figsize=(10, 5))
#
# # Define a more realistic airfoil shape
# x = np.linspace(-1, 1, 100)
# y_upper = 0.4 * (1 - (x**2))  # Upper surface of the airfoil
# y_lower = -0.1 * (1 - (x**2))  # Lower surface of the airfoil
#
# # Plot the airfoil
# ax.plot(x, y_upper, color='blue', label='Upper Surface (Lower Pressure)')
# ax.plot(x, y_lower, color='red', label='Lower Surface (Higher Pressure)')
# ax.fill_between(x, y_upper, y_lower, color='gray', alpha=0.3)
#
# # Add arrows to indicate air flow
# ax.annotate('', xy=(-1.5, 0), xytext=(-2, 0),
#             arrowprops=dict(facecolor='black', shrink=0.05))
# ax.annotate('', xy=(1.5, 0), xytext=(2, 0),
#             arrowprops=dict(facecolor='black', shrink=0.05))
#
# # Add labels for pressure areas
# ax.text(0, 0.25, 'Lower Pressure', horizontalalignment='center', fontsize=12, color='blue')
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 5))

# Define a more realistic airfoil shape
x = np.linspace(-1, 1, 100)
y_upper = 0.3 * (1 - (x**2))  # Upper surface of the airfoil
y_lower = -0.1 * np.sqrt(1 - (x**2))  # Lower surface of the airfoil

# Plot the airfoil
ax.plot(x, y_upper, color='blue', label='Upper Surface (Lower Pressure)')
ax.plot(x, y_lower, color='red', label='Lower Surface (Higher Pressure)')
ax.fill_between(x, y_upper, y_lower, color='gray', alpha=0.5)

# Add arrows to indicate airflow
ax.annotate('Airflow Direction', xy=(-1.5, 0), xytext=(-2, 0.1),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('Airflow Direction', xy=(1.5, 0), xytext=(2, 0.1),
            arrowprops=dict(facecolor='black', shrink=0.05))

# Add labels for pressure areas
ax.text(0, 0.25, 'Lower Pressure', horizontalalignment='center', fontsize=12, color='blue')
ax.text(0, -0.15, 'Higher Pressure', horizontalalignment='center', fontsize=12, color='red')

# Set limits and labels
ax.set_xlim(-2, 2)
ax.set_ylim(-0.5, 0.5)
ax.set_title('Lift Generation on an Airfoil')
ax.set_xlabel('Position Along Airfoil')
ax.set_ylabel('Height Above/Below Airfoil')
ax.axhline(0, color='black', lw=0.5)
ax.axvline(0, color='black', lw=0.5)

# Add legend
ax.legend()

# Add annotation for Bernoulli's principle
ax.text(0, -0.4, 'According to Bernoulli’s Principle,\nthe pressure above the wing is lower\nthan below, creating lift.', 
        horizontalalignment='center', fontsize=10, color='black', bbox=dict(facecolor='white', alpha=0.5))

# Show the plot
plt.grid(visible=False)
plt.show()

# %% [markdown]
# Slightly improved prompt

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 5))

# Define a more realistic airfoil shape
x = np.linspace(-1, 1, 100)
y_upper = 0.4 * (1 - (x**2))  # Upper surface of the airfoil
y_lower = -0.1 * (1 - (x**2))  # Lower surface of the airfoil

# Plot the airfoil
ax.plot(x, y_upper, color='blue', label='Upper Surface (Lower Pressure)')
ax.plot(x, y_lower, color='red', label='Lower Surface (Higher Pressure)')
ax.fill_between(x, y_upper, y_lower, color='gray', alpha=0.3)

# Add arrows to indicate air flow
ax.annotate('', xy=(-1.5, 0), xytext=(-2, 0),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('', xy=(1.5, 0), xytext=(2, 0),
            arrowprops=dict(facecolor='black', shrink=0.05))

# Add labels for pressure areas
ax.text(0, 0.25, 'Lower Pressure', horizontalalignment='center', fontsize=12, color='blue')
ax.text(0, -0.15, 'Higher Pressure', horizontalalignment='center', fontsize=12, color='red')

# Add airflow direction labels
ax.text(-1.5, 0.1, 'Airflow Direction', fontsize=10, color='black')
ax.text(1.5, 0.1, 'Airflow Direction', fontsize=10, color='black')

# Annotation for Bernoulli's Principle
ax.text(0, 0.4, 'Bernoulli’s Principle: Faster Air = Lower Pressure', fontsize=10, ha='center', bbox=dict(facecolor='white', alpha=0.5))

# Set limits and labels
ax.set_xlim(-2, 2)
ax.set_ylim(-0.5, 0.5)
ax.set_title('Lift Generation on an Airfoil')
ax.set_xlabel('Position Along Airfoil')
ax.set_ylabel('Height Above/Below Airfoil')
ax.axhline(0, color='black', lw=0.5)
ax.axvline(0, color='black', lw=0.5)

# Add legend
ax.legend()

# Hide grid lines for clarity
ax.grid(False)

# Show the plot
plt.show()

# %% [markdown]
# ## Observations
#
# - The original prompt itself produced the best results.
# - Critiquing the original code and regenerating resulted in high volatility in the results (somehow!). The results ranged from complete bonkers as compared to original plot to somewhat acceptable.
